# %% [markdown]
# # Building a Chromosome in `shadie`

# %% [markdown]
# You can find a detailed description of how chromosomes work in SLiM in the official SLiM manual - here we will just cover the basics necessary to build a chromosome in shadie.
#
# Chromosomes in SLiM are made of genomic elements. Recall that each genomic element is defined by the kinds of mutations that can occur within them. Chromosomes can be as simple or as complex as you want. Just keep in mind that a simple chromosome, while it may only reveal dynamics occurring at a limited number of loci, will be much easier to interpret and will usually allow the simulation to run faster than a complex one.

# %% [markdown]
# ## Using `shadie` defaults
# `shadie` has a default chromosome, which consists of a gene in the middle (two exons and one intron), flanked by two non-coding regions.

# %%
import shadie
default_chrom = shadie.chromosome.default()

# %% [markdown]
# You can visualize the genomic elements on a chromosome using the `draw()` function

# %%
default_chrom.draw();
# Out:
# <div class="toyplot" id="t1cf0ab93d19542608bc455e9fb09334d" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="700.0px" height="150.0px" viewBox="0 0 700.0 150.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t5af19da2c252445bba765a5d28fab63b"><g class="toyplot-coordinates-Cartesian" id="t014f547b48634a9ba38b4c08d46b4db8"><clipPath id="t9bdf24e7b7184556b125df297f71c1ae"><rect x="40.0" y="40.0" width="620.0" height="70.0"></rect></clipPath><g clip-path="url(#t9bdf24e7b7184556b125df297f71c1ae)"><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t968eb118bd654d77a216b5dec78d1e7a"><polygon points="50.0,100.0 170.0,100.0 170.0,50.0 50.0,50.0" style="fill:rgb(16.9%,51.4%,72.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (0, 2000)
# ElementType: g3
# coding: False</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t180e7c12b70c4d7d93e2a874a2f14ba6"><polygon points="170.06,100.0 290.0,100.0 290.0,50.0 170.06,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon
# interval: (2001, 4000)
# ElementType: g1
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="te6c71984968943ac89a3c38eb5539423"><polygon points="290.06,100.0 410.0,100.0 410.0,50.0 290.06,50.0" style="fill:rgb(99.2%,68.2%,38%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: intron
# interval: (4001, 6000)
# ElementType: g2
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="ted697a8bc4b046b99b5b6af3205abbbd"><polygon points="410.06,100.0 530.0,100.0 530.0,50.0 410.06,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon
# interval: (6001, 8000)
# ElementType: g1
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="td45b0c5531764f66b08040a2aeb52dac"><polygon points="530.0600000000001,100.0 650.0,100.0 650.0,50.0 530.0600000000001,50.0" style="fill:rgb(16.9%,51.4%,72.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (8001, 10000)
# ElementType: g3
# coding: False</title></polygon></g></g><g class="toyplot-coordinates-Axis" id="tf73c48a5965941539ef1f5037a415bf4" transform="translate(50.0,100.0)translate(0,10.0)"><line x1="0" y1="0" x2="600.0" y2="0" style=""></line><g><line x1="0.0" y1="0" x2="0.0" y2="-5" style=""></line><line x1="120.0" y1="0" x2="120.0" y2="-5" style=""></line><line x1="240.0" y1="0" x2="240.0" y2="-5" style=""></line><line x1="360.0" y1="0" x2="360.0" y2="-5" style=""></line><line x1="480.0" y1="0" x2="480.0" y2="-5" style=""></line><line x1="600.0" y1="0" x2="600.0" y2="-5" style=""></line></g><g><g transform="translate(0.0,6)"><text x="-2.78" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">0</text></g><g transform="translate(120.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">2000</text></g><g transform="translate(240.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">4000</text></g><g transform="translate(360.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">6000</text></g><g transform="translate(480.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">8000</text></g><g transform="translate(600.0,6)"><text x="-13.9" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">10000</text></g></g><g class="toyplot-coordinates-Axis-coordinates" style="visibility:hidden" transform=""><line x1="0" x2="0" y1="-3.0" y2="4.5" style="stroke:rgb(43.9%,50.2%,56.5%);stroke-opacity:1.0;stroke-width:1.0"></line><text x="0" y="-6" style="alignment-baseline:alphabetic;fill:rgb(43.9%,50.2%,56.5%);fill-opacity:1.0;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle"></text></g></g></g></svg><div class="toyplot-behavior"><script>(function()
# {
# var modules={};
# modules["toyplot/tables"] = (function()
#     {
#         var tables = [];
#
#         var module = {};
#
#         module.set = function(owner, key, names, columns)
#         {
#             tables.push({owner: owner, key: key, names: names, columns: columns});
#         }
#
#         module.get = function(owner, key)
#         {
#             for(var i = 0; i != tables.length; ++i)
#             {
#                 var table = tables[i];
#                 if(table.owner != owner)
#                     continue;
#                 if(table.key != key)
#                     continue;
#                 return {names: table.names, columns: table.columns};
#             }
#         }
#
#         module.get_csv = function(owner, key)
#         {
#             var table = module.get(owner, key);
#             if(table != undefined)
#             {
#                 var csv = "";
#                 csv += table.names.join(",") + "\n";
#                 for(var i = 0; i != table.columns[0].length; ++i)
#                 {
#                   for(var j = 0; j != table.columns.length; ++j)
#                   {
#                     if(j)
#                       csv += ",";
#                     csv += table.columns[j][i];
#                   }
#                   csv += "\n";
#                 }
#                 return csv;
#             }
#         }
#
#         return module;
#     })();
# modules["toyplot/root/id"] = "t1cf0ab93d19542608bc455e9fb09334d";
# modules["toyplot/root"] = (function(root_id)
#     {
#         return document.querySelector("#" + root_id);
#     })(modules["toyplot/root/id"]);
# modules["toyplot/canvas/id"] = "t5af19da2c252445bba765a5d28fab63b";
# modules["toyplot/canvas"] = (function(canvas_id)
#     {
#         return document.querySelector("#" + canvas_id);
#     })(modules["toyplot/canvas/id"]);
# modules["toyplot/menus/context"] = (function(root, canvas)
#     {
#         var wrapper = document.createElement("div");
#         wrapper.innerHTML = "<ul class='toyplot-context-menu' style='background:#eee; border:1px solid #b8b8b8; border-radius:5px; box-shadow: 0px 0px 8px rgba(0%,0%,0%,0.25); margin:0; padding:3px 0; position:fixed; visibility:hidden;'></ul>"
#         var menu = wrapper.firstChild;
#
#         root.appendChild(menu);
#
#         var items = [];
#
#         var ignore_mouseup = null;
#         function open_menu(e)
#         {
#             var show_menu = false;
#             for(var index=0; index != items.length; ++index)
#             {
#                 var item = items[index];
#                 if(item.show(e))
#                 {
#                     item.item.style.display = "block";
#                     show_menu = true;
#                 }
#                 else
#                 {
#                     item.item.style.display = "none";
#                 }

# %% [markdown]
# The `Chromosome` class object in `shadie` has a number of ways to define a chromosome. The lowest effort method is to use the `shadie.chromosome.random()` function, which will attempt to create a 'realistic' chromosome of a certain length, in which exons and non-coding regions are interspersed, and introns always occur between exons.
#
# Arguments:
#
# - genome size (int): length of chromosome in base pairs
# - intron (list): list of ElementTypes that can be used as introns
# - exon (list): list of ElementTypes that can be used as exons
# - noncds (list): list of ElementTypes that can be used as non-coding sequences
# - intron_scale (int): average length of each intron
# - cds_scale (int): average length of each exon
# - noncds_scale (int): average length of each non-coding sequence
# - seed (int): use to generate the same chromosome consistently - otherwise a different random chromosome will be generated each time
#
# Use `shadie.chromosome.random??` to see defaults

# %%
#create a random chromosome - if no arguments are supplied, defaults will be used
random_chrom = shadie.chromosome.random()

# %% [markdown]
# ## Visualizing your chromosome
# The `draw()` function will generate a static `toyplot` of the chromosome. However over the different elements to see metadata.

# %%
random_chrom.draw();
# Out:
# <div class="toyplot" id="t143adc5dd5374b4fb7e8e7ecedfffd86" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="700.0px" height="150.0px" viewBox="0 0 700.0 150.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t9b30c36f33d340ff91bc4936220f29f2"><g class="toyplot-coordinates-Cartesian" id="t8697e3544f774d37b381ddafe4e5c9b0"><clipPath id="tc11bba55ed574b45a2e9075173a64f32"><rect x="40.0" y="40.0" width="620.0" height="70.0"></rect></clipPath><g clip-path="url(#tc11bba55ed574b45a2e9075173a64f32)"><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t83935941ed194ceabd84c6f564c8539e"><polygon points="50.0,100.0 355.1950697769176,100.0 355.1950697769176,50.0 50.0,50.0" style="fill:rgb(16.9%,51.4%,72.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (1, 9988)
# ElementType: g3
# coding: False</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t7fb78bce251c44fdb6a3da6915066fce"><polygon points="355.2256290108995,100.0 396.38891718447593,100.0 396.38891718447593,50.0 355.2256290108995,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon
# interval: (9989, 11336)
# ElementType: g1
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tfe1217ab0e134ad199c99ff6eaf31c6b"><polygon points="396.41947641845775,100.0 598.1409799327697,100.0 598.1409799327697,50.0 396.41947641845775,50.0" style="fill:rgb(16.9%,51.4%,72.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (11337, 17938)
# ElementType: g3
# coding: False</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="teba9410d276b4ab5973cfc3523cdbfd4"><polygon points="598.1715391667516,100.0 613.35947845574,100.0 613.35947845574,50.0 598.1715391667516,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon
# interval: (17939, 18436)
# ElementType: g1
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t5480c301dd8d423bbd50fb895d8f596d"><polygon points="613.3900376897219,100.0 650.0,100.0 650.0,50.0 613.3900376897219,50.0" style="fill:rgb(16.9%,51.4%,72.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (18437, 19635)
# ElementType: g3
# coding: False</title></polygon></g></g><g class="toyplot-coordinates-Axis" id="t73b7435e165047a997de84b2cad20540" transform="translate(50.0,100.0)translate(0,10.0)"><line x1="0" y1="0" x2="600.0" y2="0" style=""></line><g><line x1="30.52867474788632" y1="0" x2="30.52867474788632" y2="-5" style=""></line><line x1="122.20637669349088" y1="0" x2="122.20637669349088" y2="-5" style=""></line><line x1="213.88407863909546" y1="0" x2="213.88407863909546" y2="-5" style=""></line><line x1="305.5617805847" y1="0" x2="305.5617805847" y2="-5" style=""></line><line x1="397.2394825303046" y1="0" x2="397.2394825303046" y2="-5" style=""></line><line x1="488.9171844759091" y1="0" x2="488.9171844759091" y2="-5" style=""></line><line x1="580.5948864215137" y1="0" x2="580.5948864215137" y2="-5" style=""></line></g><g><g transform="translate(30.52867474788632,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">1000</text></g><g transform="translate(122.20637669349088,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">4000</text></g><g transform="translate(213.88407863909546,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">7000</text></g><g transform="translate(305.5617805847,6)"><text x="-13.9" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">10000</text></g><g transform="translate(397.2394825303046,6)"><text x="-13.9" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">13000</text></g><g transform="translate(488.9171844759091,6)"><text x="-13.9" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">16000</text></g><g transform="translate(580.5948864215137,6)"><text x="-13.9" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">19000</text></g></g><g class="toyplot-coordinates-Axis-coordinates" style="visibility:hidden" transform=""><line x1="0" x2="0" y1="-3.0" y2="4.5" style="stroke:rgb(43.9%,50.2%,56.5%);stroke-opacity:1.0;stroke-width:1.0"></line><text x="0" y="-6" style="alignment-baseline:alphabetic;fill:rgb(43.9%,50.2%,56.5%);fill-opacity:1.0;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle"></text></g></g></g></svg><div class="toyplot-behavior"><script>(function()
# {
# var modules={};
# modules["toyplot/tables"] = (function()
#     {
#         var tables = [];
#
#         var module = {};
#
#         module.set = function(owner, key, names, columns)
#         {
#             tables.push({owner: owner, key: key, names: names, columns: columns});
#         }
#
#         module.get = function(owner, key)
#         {
#             for(var i = 0; i != tables.length; ++i)
#             {
#                 var table = tables[i];
#                 if(table.owner != owner)
#                     continue;
#                 if(table.key != key)
#                     continue;
#                 return {names: table.names, columns: table.columns};
#             }
#         }
#
#         module.get_csv = function(owner, key)
#         {
#             var table = module.get(owner, key);
#             if(table != undefined)
#             {
#                 var csv = "";
#                 csv += table.names.join(",") + "\n";
#                 for(var i = 0; i != table.columns[0].length; ++i)
#                 {
#                   for(var j = 0; j != table.columns.length; ++j)
#                   {
#                     if(j)
#                       csv += ",";
#                     csv += table.columns[j][i];
#                   }
#                   csv += "\n";
#                 }
#                 return csv;
#             }
#         }
#
#         return module;
#     })();
# modules["toyplot/root/id"] = "t143adc5dd5374b4fb7e8e7ecedfffd86";
# modules["toyplot/root"] = (function(root_id)
#     {
#         return document.querySelector("#" + root_id);
#     })(modules["toyplot/root/id"]);
# modules["toyplot/canvas/id"] = "t9b30c36f33d340ff91bc4936220f29f2";
# modules["toyplot/canvas"] = (function(canvas_id)
#     {
#         return document.querySelector("#" + canvas_id);
#     })(modules["toyplot/canvas/id"]);
# modules["toyplot/menus/context"] = (function(root, canvas)
#     {
#         var wrapper = document.createElement("div");
#         wrapper.innerHTML = "<ul class='toyplot-context-menu' style='background:#eee; border:1px solid #b8b8b8; borde

# %% [markdown]
# The `inspect()` function generates an interactive plot using the `altair` package, which allows you to zoom in on parts of your chromosome. This is useful for long or complex chromosomes. Click and draw in the lower plot to zoom in on a portion of the chromosome. Hover for more info.

# %%
random_chrom.inspect()
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# The chromosome object has attributes, which you can access to check the setting before you begin your simulation:

# %%
# mutation types
random_chrom.mutations
# Out:
# [<MutationType: m3, 0.8, e, (0.04,)>,
#  <MutationType: m1, 0.5, f, (0.0,)>,
#  <MutationType: m2, 0.1, g, (-3.0, 1.5)>]

# %%
# element types
random_chrom.elements
# Out:
# [<ElementType: exon, g1, ['m2', 'm3'], (8, 0.1)>,
#  <ElementType: noncds, g3, ['m1'], [1]>]

# %%
# dataframe of all the genomic elements
random_chrom.data
# Out:
#          name  start    end eltype  \
# 0      noncds      1   9988     g3
# 9988     exon   9989  11336     g1
# 11336  noncds  11337  17938     g3
# 17938    exon  17939  18436     g1
# 18436  noncds  18437  19635     g3
#
#                                                 script  coding
# 0               <ElementType: noncds, g3, ['m1'], [1]>       0
# 9988   <ElementType: exon, g1, ['m2', 'm3'], (8, 0.1)>       1
# 11336           <ElementType: noncds, g3, ['m1'], [1]>       0
# 17938  <ElementType: exon, g1, ['m2', 'm3'], (8, 0.1)>       1
# 18436           <ElementType: noncds, g3, ['m1'], [1]>       0

# %%
random_chrom.review("chromosome")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 random_chrom.review("chromosome")
#
# AttributeError: 'ChromosomeRandom' object has no attribute 'review'

# %% [markdown]
# ## Creating a Custom Chromosome
# Finally, you can define your own chromosome by providing a pandas dataframe that contains, at minimum, the `name` of the genomic element (as defined by you *or* using `shadie` defaults), the `start base` and the `end base`. Alternatively, you can provide the internal `idx` of the genomic element (in place of the `name`). You must provide a GenomeList class object and your genomic elements must be defined in the list.

# %% [markdown]
# ### Interactive Plot
# You can use the `review()` function to generate an interactive plot to inspect your chromosome structure further. Draw a region on the bottom plot to view that region in the top plot.

# %%
default_chrom.
# Out:
#   Input In [10]
#     default_chrom.
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Random Chromosome with Custom Mutation Types & Genomic Element Types

# %%
from shadie import ElementList
from shadie import ElementType
from shadie import MutationType
from shadie import MutationList

#create your custom mutation types and save to a MutationList
mut1 = MutationType(0.5, "f", 0)
mut2 = MutationType(0.5, "e", 0.4)
mut3 = MutationType(0.5, "n", 0.4, .1)
mut4 = MutationType(0.5, "w", 0.3, 0.2)
mut5 = MutationType(0.5, "g", -0.4, .1)

mutlist = MutationList(mut1, mut2, mut3, mut4, mut5)

#create your custom genomic element types and save to an ElementList
noncod = ElementType(mut1, 1, altname = "nc")
exon1 = ElementType([mut2, mut5], [1, 1], altname = "ex1")
exon2 = ElementType([mut2, mut3, mut4], [9, 1, .02], altname = "ex2")
intron1 = ElementType([mut2, mut5], [1, 1], altname = "int1")
intron2 = ElementType([mut2, mut5], [1, 1], altname = "int2")

mycustomlist = ElementList(mutlist, noncod, exon1, exon2, intron1, intron2)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 from shadie import ElementList
#       2 from shadie import ElementType
#       3 from shadie import MutationType
#
# ImportError: cannot import name 'ElementList' from 'shadie' (/Users/elissa/code/git/hacks/shadie/shadie/__init__.py)

# %%
from shadie import Build

#initialize the Build class object
custom_build = Build(
    exons = [exon1, exon2], 
    introns = [intron1, intron2], 
    noncoding = [noncod], 
    elementlist = mycustomlist)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 from shadie import Build
#       3 #initialize the Build class object
#       4 custom_build = Build(
#       5     exons = [exon1, exon2],
#       6     introns = [intron1, intron2],
#       7     noncoding = [noncod],
#       8     elementlist = mycustomlist)
#
# ImportError: cannot import name 'Build' from 'shadie' (/Users/elissa/code/git/hacks/shadie/shadie/__init__.py)

# %%
#run the same random function
custom_build.random()
# Out:
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Chromosome complete!

# %%
from shadie import Chromosome

customized_chrom = Chromosome(genome = custom_build)

# %%
customized_chrom.review("elements")
# Out:
# Genomic Elements:
#          name    start   finish eltype  \
# 0          nc        0     3847     g5
# 3848      ex1     3848     4063     g6
# 4064     int1     4064     4639     g8
# 4640      ex2     4640     4900     g7
# 4901       nc     4901     5780     g5
# ...       ...      ...      ...    ...
# 999020   int2   999020   999305     g9
# 999306    ex1   999306   999556     g6
# 999557   int1   999557  1000162     g8
# 1000163   ex1  1000163  1000346     g6
# 1000347    nc  1000347   999999     g5
#
#                                                     script       type
# 0                 'g5', c(m5),c(1), mmJukesCantor(1e-06/3)  noncoding
# 3848       'g6', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)       exon
# 4064       'g8', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)     intron
# 4640     'g7', c(m6, m7, m8),c(9, 1, 0.02), mmJukesCant...       exon
# 4901              'g5', c(m5),c(1), mmJukesCantor(1e-06/3)  noncoding
# ...                                                    ...        ...
# 999020     'g9', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)     intron
# 999306     'g6', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)       exon
# 999557     'g8', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)     intron
# 1000163    'g6', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)       exon
# 1000347           'g5', c(m5),c(1), mmJukesCantor(1e-06/3)  noncoding
#
# [1705 rows x 6 columns]

# %%
import pandas as pd
final_chromosome.genome["name"]

for index, row in final_chromosome.genome.iterrows():
    if pd.isna(row['name']):
        print(row['type'])
    else: 
        print(row['name'])
# Out:
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding

# %%
customized_chrom.review("chromosome")
# Out:
# Chromosome Summary
# # of Genes: 220
# Average # exons per gene: 3.8727272727272726
# Average exon length: 259.46596244131456 nt
# Average # introns per gene: 2.8727272727272726
# Average introns length: 452.40822784810126 nt
#
# Static Chromosome Plot:
# <div class="toyplot" id="tb40ff5d29ae14e22aea8aa46f81b8bf4" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="3000.0px" height="200.0px" viewBox="0 0 3000.0 200.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t41e8998361944cd188a69d0495f63082"><g class="toyplot-coordinates-Cartesian" id="tda58501b7e4940a18e6ff8f94acf6d22"><clipPath id="t43ecd3b3d9ca476fb883d90e733fab62"><rect x="40.0" y="40.0" width="2920.0" height="120.0"></rect></clipPath><g clip-path="url(#t43ecd3b3d9ca476fb883d90e733fab62)"><g class="toyplot-mark-Range" style="stroke:none" id="ta0dcfc221af148eb8e58334d2f1d2956"><g class="toyplot-Series"><rect class="toyplot-Datum" x="50.0" y="50.0" width="11.15243010675296" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t74a2d2af60294ae7b2f8f6e919985e23"><g class="toyplot-Series"><rect class="toyplot-Datum" x="61.15532910080202" y="50.0" width="0.6232837205489687" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t5cf36de5d91146ba8c038f0f57d4742e"><g class="toyplot-Series"><rect class="toyplot-Datum" x="61.78151181540006" y="50.0" width="1.666921578212353" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t88340ff0fbbc4c8cae485af06ef6a6c2"><g class="toyplot-Series"><rect class="toyplot-Datum" x="63.45133238766148" y="50.0" width="0.7537384527568918" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t18b64431de7b40bc87f8b721b56e3924"><g class="toyplot-Series"><rect class="toyplot-Datum" x="64.20796983446743" y="50.0" width="2.54821576912812" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t0dfee1fdb7104631883ff6d64284ebf1"><g class="toyplot-Series"><rect class="toyplot-Datum" x="66.75908459764462" y="50.0" width="1.316143298275506" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t5459ea3dde054985864b48ce6491c544"><g class="toyplot-Series"><rect class="toyplot-Datum" x="68.07812688996918" y="50.0" width="4.606501543964242" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t892f7d81d9ce488c879ed96412b17b9d"><g class="toyplot-Series"><rect class="toyplot-Datum" x="72.68752742798249" y="50.0" width="1.3045473220792445" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t621ce3aa92e8407f955c8bdfb325be46"><g class="toyplot-Series"><rect class="toyplot-Datum" x="73.9949737441108" y="50.0" width="1.142203655331599" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t589368b362c44d6b851255f085ef9c33"><g class="toyplot-Series"><rect class="toyplot-Datum" x="75.14007639349146" y="50.0" width="0.6464756729414916" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="tbc1565eac38344 ...

# %%
customized_chrom.review("interactive")
# Out:
# Interactive altair chromosome map:
# <div id="altair-viz-66b5e872d5574a3aaf7b7f1087efb7ff"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-66b5e872d5574a3aaf7b7f1087efb7ff") {
#       outputDiv = document.getElementById("altair-viz-66b5e872d5574a3aaf7b7f1087efb7ff");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "vconcat": [{"mark": "rect", "encoding": {"color": {"type": "nominal", "field": "altname", "scale": {"domain": ["ex1", "ex2", "int1", "int2", "nc"], "range": ["mediumvioletred", "lightcoral", "lightgoldenrodyellow", "gold", "cornflowerblue"]}}, "tooltip": [{"type": "nominal", "field": "type", "title": "Element Type"}, {"type": "nominal", "field": "altname", "title": "Name"}, {"type": "quantitative", "field": "length", "title": "Length"}, {"type": "quantitative", "field": "x1", "title": "Start"}, {"type": "quantitative", "field": "x2", "title": "Stop"}], "x": {"type": "quantitative", "field": "x1", "scale": {"domain": {"selection": "selector002"}}, "title": null}, "x2": {"field": "x2"}, "y": {"type": "quantitative", "axis": null, "field": "y1"}, "y2": {"field": "y2"}}, "height": 80, "selection": {"selector002": {"type": "interval", "encodings": ["x"], "mark": {"fill": "red", "fillOpacity": 0.7}}}, "width": 850}, {"mark": "rect", "encoding": {"color": {"type": "nominal", "field": "altname", "scale": {"domain": ["ex1", "ex2", "int1", "int2", "nc"], "range": ["mediumvioletred", "lightcoral", "lightgoldenrodyellow", "gold", "cornflowerblue"]}}, "tooltip": [{"type": "nominal", "field": "type", "title": "Element Type"}, {"type": "nominal", "field": "altname", "title": "Name"}, {"type": "quantitative", "field": "length", "title": "Length"}, {"type": "quantitative", "field": "x1", "title": "Start"}, {"type": "quantitative", "field": "x2", "title": "Stop"}], "x": {"type": "quantitative", "axis": {"title": "Base Pairs"}, "field": "x1"}, "x2": {"field": "x2"}, "y": {"type": "quantitative", "axis": null, "field": "y1"}, "y2": {"field": "y2"}}, "height": 40, "selection": {"selector002": {"type": "interval", "encodings": ["x"], "mark": {"fill": "red", "fillOpacity": 0.7}}}, "width": 850}], "data": {"name": "data-2d22ffd5ccd88531e548fe92d354df43"}, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-2d22ffd5ccd88531e548fe92d354df43": [{"type": "noncoding", "altname": "nc", "x1": 0, "x2": 3847.0, "y1": 0, "y2": 1, "length": 3847.0}, {"type": "exon", "altname": "ex1", "x1": 3848, "x2": 4063.0, "y1": 0, "y2": 1, "length": 215.0}, {"type": "intron", "altname": "int1", "x1": 4064, "x2": 4639.0, "y1": 0, "y2": 1, "length": 575.0}, {"type": "exon", "altname": "ex2", "x1": 4640, "x2": 4900.0, "y1": 0, "y2": 1, "length": 260.0}, {"type": "noncoding", "altname": "nc", "x1": 4901, "x2": 5780.0, "y1": 0, "y2": 1, "length": 879.0}, {"type": "exon", "altname": "ex2", "x1": 5781, "x2": 6235.0, "y1": 0, "y2": 1, "length": 454.0}, {"type": "noncoding", "altname": "nc", "x1": 6236, "x2": 7825.0, "y1": 0, "y2": 1, "length": 1589.0}, {"type": "exon", "altname": "ex2", "x1": 7826, "x2": 8276.0, "y1": 0, "y2": 1, "length": 450.0}, {"type": "intron", "altname": "int1", "x1": 8277, "x2": 8671.0, "y1": 0, "y2": 1, "length": 394.0}, {"type": "exon", "altname": "ex1", "x1": 8672, "x2": 8895.0, "y1": 0, "y2": 1, "length": 223.0}, {"type": "intron", "altname": "int1", "x1": 8896, "x2": 9321.0, "y1": 0, "y2": 1, "length": 425.0}, {"type": "exon", "altname": "ex2", "x1": 9322, "x2": 9630.0, "y1": 0, "y2": 1, "length": 308.0}, {"type": "intron", "altname": "int1", "x1": 9631, "x2": 10137.0, "y1": 0, "y2": 1, "length": 506.0}, {"type": "exon", "altname": "ex1", "x1": 10138, "x2": 10437.0, "y1": 0, "y2": 1, "length": 299.0}, {"type": "noncoding", "altname": "nc", "x1": 10438, "x2": 10812.0, "y1": 0, "y2": 1, "length": 374.0}, {"type": "exon", "altname": "ex2", "x1": 10813, "x2": 10978.0, "y1": 0, "y2": 1, "length": 165.0}, {"type": "noncoding", "altname": "nc", "x1": 10979, "x2": 12614.0, "y1": 0, "y2": 1, "length": 1635.0}, {"type": "exon", "altname": "ex1", "x1": 12615, "x2": 12927.0, "y1": 0, "y2": 1, "length": 312.0}, {"type": "noncoding", "altname": "nc", "x1": 12928, "x2": 13763.0, "y1": 0, "y2": 1, "length": 835.0}, {"type": "exon", "altname": "ex1", "x1": 1376 ...
