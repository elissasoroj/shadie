# %% [markdown]
# # Building a Chromosome for `shadie`
#
# There are many ways to build a chromosome in shadie. This tutorial assumes a basic understanding of how chromosomes work in SLiM - please refer to the [SLiM manual](https://messerlab.org/slim/) for specifics.

# %%
import shadie

# %% [markdown]
# ## Default chromsome
# The default chromosome in `shadie` is 10,000 bp long and has a single gene. There is a 2,000bp coding region flanked by two 2,000bp non-coing regions. You can access this chromosome using `shadie.chromosome.default()`

# %%
default_chrom = shadie.chromosome.default()

default_chrom.draw(); #note: semicolon tells toyplot to omit printing object data
# Out:
# <div class="toyplot" id="tee729475b2e343d29440b568fd1bbff7" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="700.0px" height="150.0px" viewBox="0 0 700.0 150.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t221abeb99d874052ad103640b8b1392d"><g class="toyplot-coordinates-Cartesian" id="t11cb759cea16480c94615b3f58723d82"><clipPath id="t0eb69d2ed956462abae157bbdff58feb"><rect x="40.0" y="40.0" width="620.0" height="70.0"></rect></clipPath><g clip-path="url(#t0eb69d2ed956462abae157bbdff58feb)"><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tc6095af4b2e94527bf5be66b5eac39e1"><polygon points="50.0,100.0 170.0,100.0 170.0,50.0 50.0,50.0" style="fill:rgb(16.9%,51.4%,72.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (0, 2000)
# ElementType: g3
# coding: False</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t15f6ff59b8cc47faa275641fab52f843"><polygon points="170.06,100.0 290.0,100.0 290.0,50.0 170.06,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon
# interval: (2001, 4000)
# ElementType: g1
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t8ff89c7dd0004c67bff3bfdf4e70096a"><polygon points="290.06,100.0 410.0,100.0 410.0,50.0 290.06,50.0" style="fill:rgb(99.2%,68.2%,38%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: intron
# interval: (4001, 6000)
# ElementType: g2
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tb257eda30abc4969b2b1db6e2498231a"><polygon points="410.06,100.0 530.0,100.0 530.0,50.0 410.06,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon
# interval: (6001, 8000)
# ElementType: g1
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t935984283ec749b990c90798b2bfb98b"><polygon points="530.0600000000001,100.0 650.0,100.0 650.0,50.0 530.0600000000001,50.0" style="fill:rgb(16.9%,51.4%,72.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (8001, 10000)
# ElementType: g3
# coding: False</title></polygon></g></g><g class="toyplot-coordinates-Axis" id="tb21c37cf4fcd480ab5eba52714c37351" transform="translate(50.0,100.0)translate(0,10.0)"><line x1="0" y1="0" x2="600.0" y2="0" style=""></line><g><line x1="0.0" y1="0" x2="0.0" y2="-5" style=""></line><line x1="120.0" y1="0" x2="120.0" y2="-5" style=""></line><line x1="240.0" y1="0" x2="240.0" y2="-5" style=""></line><line x1="360.0" y1="0" x2="360.0" y2="-5" style=""></line><line x1="480.0" y1="0" x2="480.0" y2="-5" style=""></line><line x1="600.0" y1="0" x2="600.0" y2="-5" style=""></line></g><g><g transform="translate(0.0,6)"><text x="-2.78" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">0</text></g><g transform="translate(120.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">2000</text></g><g transform="translate(240.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">4000</text></g><g transform="translate(360.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">6000</text></g><g transform="translate(480.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">8000</text></g><g transform="translate(600.0,6)"><text x="-13.9" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">10000</text></g></g><g class="toyplot-coordinates-Axis-coordinates" style="visibility:hidden" transform=""><line x1="0" x2="0" y1="-3.0" y2="4.5" style="stroke:rgb(43.9%,50.2%,56.5%);stroke-opacity:1.0;stroke-width:1.0"></line><text x="0" y="-6" style="alignment-baseline:alphabetic;fill:rgb(43.9%,50.2%,56.5%);fill-opacity:1.0;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle"></text></g></g></g></svg><div class="toyplot-behavior"><script>(function()
# {
# var modules={};
# modules["toyplot/tables"] = (function()
#     {
#         var tables = [];
#
#         var module = {};
#
#         module.set = function(owner, key, names, columns)
#         {
#             tables.push({owner: owner, key: key, names: names, columns: columns});
#         }
#
#         module.get = function(owner, key)
#         {
#             for(var i = 0; i != tables.length; ++i)
#             {
#                 var table = tables[i];
#                 if(table.owner != owner)
#                     continue;
#                 if(table.key != key)
#                     continue;
#                 return {names: table.names, columns: table.columns};
#             }
#         }
#
#         module.get_csv = function(owner, key)
#         {
#             var table = module.get(owner, key);
#             if(table != undefined)
#             {
#                 var csv = "";
#                 csv += table.names.join(",") + "\n";
#                 for(var i = 0; i != table.columns[0].length; ++i)
#                 {
#                   for(var j = 0; j != table.columns.length; ++j)
#                   {
#                     if(j)
#                       csv += ",";
#                     csv += table.columns[j][i];
#                   }
#                   csv += "\n";
#                 }
#                 return csv;
#             }
#         }
#
#         return module;
#     })();
# modules["toyplot/root/id"] = "tee729475b2e343d29440b568fd1bbff7";
# modules["toyplot/root"] = (function(root_id)
#     {
#         return document.querySelector("#" + root_id);
#     })(modules["toyplot/root/id"]);
# modules["toyplot/canvas/id"] = "t221abeb99d874052ad103640b8b1392d";
# modules["toyplot/canvas"] = (function(canvas_id)
#     {
#         return document.querySelector("#" + canvas_id);
#     })(modules["toyplot/canvas/id"]);
# modules["toyplot/menus/context"] = (function(root, canvas)
#     {
#         var wrapper = document.createElement("div");
#         wrapper.innerHTML = "<ul class='toyplot-context-menu' style='background:#eee; border:1px solid #b8b8b8; border-radius:5px; box-shadow: 0px 0px 8px rgba(0%,0%,0%,0.25); margin:0; padding:3px 0; position:fixed; visibility:hidden;'></ul>"
#         var menu = wrapper.firstChild;
#
#         root.appendChild(menu);
#
#         var items = [];
#
#         var ignore_mouseup = null;
#         function open_menu(e)
#         {
#             var show_menu = false;
#             for(var index=0; index != items.length; ++index)
#             {
#                 var item = items[index];
#                 if(item.show(e))
#                 {
#                     item.item.style.display = "block";
#                     show_menu = true;
#                 }
#                 else
#                 {
#                     item.item.style.display = "none";
#                 }

# %% [markdown]
# ## Random Chromosome
# The random chromosome function in `shadie` is designed to generate a random chromosome with somewhat 'realistic' structure by ensuring that all coding regions fall between non-coding regions and exons alternate with introns.

# %%
#re-run this code block to see different chromosome 
#structures generated by the random chromosome function

shadie.chromosome.random().draw();
# Out:
# <div class="toyplot" id="t467c63d9510d4393849143f098d07880" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="700.0px" height="150.0px" viewBox="0 0 700.0 150.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t3f23e34919da4b28a780debb0d77088e"><g class="toyplot-coordinates-Cartesian" id="t666b1bcad80148fa84976504d343aabe"><clipPath id="tef7965b8a7b14f558fd43613c80c6c96"><rect x="40.0" y="40.0" width="620.0" height="70.0"></rect></clipPath><g clip-path="url(#tef7965b8a7b14f558fd43613c80c6c96)"><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t2813b7fcb8f743958b9a8f5d90c66274"><polygon points="50.0,100.0 248.64986498649864,100.0 248.64986498649864,50.0 50.0,50.0" style="fill:rgb(16.9%,51.4%,72.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (1, 6622)
# ElementType: g3
# coding: False</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="td3fe0da7b93c49edbb90a350854eea81"><polygon points="248.67986798679866,100.0 256.6906690669067,100.0 256.6906690669067,50.0 248.67986798679866,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon
# interval: (6623, 6890)
# ElementType: g1
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t9cfdbc2128384a14b069b368bc54b8a1"><polygon points="256.72067206720675,100.0 650.0,100.0 650.0,50.0 256.72067206720675,50.0" style="fill:rgb(16.9%,51.4%,72.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (6891, 19999)
# ElementType: g3
# coding: False</title></polygon></g></g><g class="toyplot-coordinates-Axis" id="ta3c00f1f38c242efb4d19052d872c470" transform="translate(50.0,100.0)translate(0,10.0)"><line x1="0" y1="0" x2="600.0" y2="0" style=""></line><g><line x1="29.972997299729972" y1="0" x2="29.972997299729972" y2="-5" style=""></line><line x1="119.98199819981998" y1="0" x2="119.98199819981998" y2="-5" style=""></line><line x1="209.99099909991" y1="0" x2="209.99099909991" y2="-5" style=""></line><line x1="300.0" y1="0" x2="300.0" y2="-5" style=""></line><line x1="390.00900090009003" y1="0" x2="390.00900090009003" y2="-5" style=""></line><line x1="480.01800180018" y1="0" x2="480.01800180018" y2="-5" style=""></line><line x1="570.02700270027" y1="0" x2="570.02700270027" y2="-5" style=""></line></g><g><g transform="translate(29.972997299729972,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">1000</text></g><g transform="translate(119.98199819981998,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">4000</text></g><g transform="translate(209.99099909991,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">7000</text></g><g transform="translate(300.0,6)"><text x="-13.9" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">10000</text></g><g transform="translate(390.00900090009003,6)"><text x="-13.9" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">13000</text></g><g transform="translate(480.01800180018,6)"><text x="-13.9" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">16000</text></g><g transform="translate(570.02700270027,6)"><text x="-13.9" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">19000</text></g></g><g class="toyplot-coordinates-Axis-coordinates" style="visibility:hidden" transform=""><line x1="0" x2="0" y1="-3.0" y2="4.5" style="stroke:rgb(43.9%,50.2%,56.5%);stroke-opacity:1.0;stroke-width:1.0"></line><text x="0" y="-6" style="alignment-baseline:alphabetic;fill:rgb(43.9%,50.2%,56.5%);fill-opacity:1.0;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle"></text></g></g></g></svg><div class="toyplot-behavior"><script>(function()
# {
# var modules={};
# modules["toyplot/tables"] = (function()
#     {
#         var tables = [];
#
#         var module = {};
#
#         module.set = function(owner, key, names, columns)
#         {
#             tables.push({owner: owner, key: key, names: names, columns: columns});
#         }
#
#         module.get = function(owner, key)
#         {
#             for(var i = 0; i != tables.length; ++i)
#             {
#                 var table = tables[i];
#                 if(table.owner != owner)
#                     continue;
#                 if(table.key != key)
#                     continue;
#                 return {names: table.names, columns: table.columns};
#             }
#         }
#
#         module.get_csv = function(owner, key)
#         {
#             var table = module.get(owner, key);
#             if(table != undefined)
#             {
#                 var csv = "";
#                 csv += table.names.join(",") + "\n";
#                 for(var i = 0; i != table.columns[0].length; ++i)
#                 {
#                   for(var j = 0; j != table.columns.length; ++j)
#                   {
#                     if(j)
#                       csv += ",";
#                     csv += table.columns[j][i];
#                   }
#                   csv += "\n";
#                 }
#                 return csv;
#             }
#         }
#
#         return module;
#     })();
# modules["toyplot/root/id"] = "t467c63d9510d4393849143f098d07880";
# modules["toyplot/root"] = (function(root_id)
#     {
#         return document.querySelector("#" + root_id);
#     })(modules["toyplot/root/id"]);
# modules["toyplot/canvas/id"] = "t3f23e34919da4b28a780debb0d77088e";
# modules["toyplot/canvas"] = (function(canvas_id)
#     {
#         return document.querySelector("#" + canvas_id);
#     })(modules["toyplot/canvas/id"]);
# modules["toyplot/menus/context"] = (function(root, canvas)
#     {
#         var wrapper = document.createElement("div");
#         wrapper.innerHTML = "<ul class='toyplot-context-menu' style='background:#eee; border:1px solid #b8b8b8; border-radius:5px; box-shadow: 0px 0px 8px rgba(0%,0%,0%,0.25); margin:0; padding:3px 0; position:fixed; visibility:hidden;'></ul>"
#         var menu = wrapper.firstChild;
#
#         root.appendChild(menu);
#
#         var items = [];
#
#         var ignore_mouseup = null;
#         function open_menu(e)
#         {
#             var show_menu = false;
#             for(var index=0; index != items.length; ++index)
#             {
#                 var item = items[index];
#                 if(item.show(e))
#                 {
#                     item.item.style.display = "block";
#                     show_menu = true;
#                 }
#                 else
#                 {
#                     item.item.style.display = "none";
#                 }
#             }
#
#             if(show_menu)
#             {
#                 ignore_mouseup = true;
#                 menu.style.left = (e.clientX + 1) + "px";
#                 menu.style.top = (e.cli

# %% [markdown]
# You can specify the length (in base pairs) of the chromosome using the `genome_size` argument. The length of non-coding (noncds), introns, and exons (cds) is controlled by the `noncds_scale`, `intron_scale`, and `cds_scale` arguments. Remember to use a seed if you want to be able to regenerate your exact chromosome again.

# %%
shadie.chromosome.random(genome_size = 50001,
                         noncds_scale = 3000,
                         cds_scale = 2000,
                         intron_scale = 2000,
                         seed = 123456,
                        ).draw();
# Out:
# <div class="toyplot" id="t78ff68c2c21140b8a8d3716412252a69" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="700.0px" height="150.0px" viewBox="0 0 700.0 150.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="tb9dc75eba4a94f0382b577885a95b3dc"><g class="toyplot-coordinates-Cartesian" id="tfba115e39bb44634a52a573b52b0f0bf"><clipPath id="t4859490c092340948f36eebe090d4c78"><rect x="40.0" y="40.0" width="620.0" height="70.0"></rect></clipPath><g clip-path="url(#t4859490c092340948f36eebe090d4c78)"><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t206c5bd44ce444e382701d5ba659103f"><polygon points="50.0,100.0 77.67255345106902,100.0 77.67255345106902,50.0 50.0,50.0" style="fill:rgb(16.9%,51.4%,72.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (1, 2307)
# ElementType: g3
# coding: False</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tde3ae91f0d084b25939a7d62bc122c20"><polygon points="77.68455369107382,100.0 97.76095521910437,100.0 97.76095521910437,50.0 77.68455369107382,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon
# interval: (2308, 3981)
# ElementType: g1
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="ta5d2685aa54146fa8cf70825ce4cb7f8"><polygon points="97.77295545910918,100.0 135.21370427408547,100.0 135.21370427408547,50.0 97.77295545910918,50.0" style="fill:rgb(16.9%,51.4%,72.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (3982, 7102)
# ElementType: g3
# coding: False</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tf496e396f913453ea8fd36c39e7e50a4"><polygon points="135.2257045140903,100.0 158.05016100322007,100.0 158.05016100322007,50.0 135.2257045140903,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon
# interval: (7103, 9005)
# ElementType: g1
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t030043324c6148c4a9c81d60fece2f52"><polygon points="158.06216124322486,100.0 158.60217204344087,100.0 158.60217204344087,50.0 158.06216124322486,50.0" style="fill:rgb(99.2%,68.2%,38%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: intron
# interval: (9006, 9051)
# ElementType: g2
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="taca11887c1094396998d5b5456b70c85"><polygon points="158.61417228344567,100.0 160.43820876417527,100.0 160.43820876417527,50.0 158.61417228344567,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon
# interval: (9052, 9204)
# ElementType: g1
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tb6cb8924053c4fef84c74afea07c5549"><polygon points="160.4502090041801,100.0 174.6704934098682,100.0 174.6704934098682,50.0 160.4502090041801,50.0" style="fill:rgb(99.2%,68.2%,38%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: intron
# interval: (9205, 10390)
# ElementType: g2
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t585ec3ffcd594e809913219f90a94b2a"><polygon points="174.68249364987298,100.0 176.93853877077544,100.0 176.93853877077544,50.0 174.68249364987298,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon
# interval: (10391, 10579)
# ElementType: g1
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tafd4a56b151e4ff2a46b24e1268fbe2b"><polygon points="176.95053901078023,100.0 193.81087621752437,100.0 193.81087621752437,50.0 176.95053901078023,50.0" style="fill:rgb(99.2%,68.2%,38%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: intron
# interval: (10580, 11985)
# ElementType: g2
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tc9d23794022540c8a15764b3294a490e"><polygon points="193.82287645752916,100.0 200.41100822016443,100.0 200.41100822016443,50.0 193.82287645752916,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon
# interval: (11986, 12535)
# ElementType: g1
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t4d08644f96fe4da2b816d5b769d09264"><polygon points="200.4230084601692,100.0 200.6870137402748,100.0 200.6870137402748,50.0 200.4230084601692,50.0" style="fill:rgb(99.2%,68.2%,38%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: intron
# interval: (12536, 12558)
# ElementType: g2
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="td6886a96fe5e4481829f306afa608c85"><polygon points="200.6990139802796,100.0 201.65903318066364,100.0 201.65903318066364,50.0 200.6990139802796,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon
# interval: (12559, 12639)
# ElementType: g1
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="te93920b4a8a64576abf644fa13d6d21a"><polygon points="201.6710334206684,100.0 210.21520430408611,100.0 210.21520430408611,50.0 201.6710334206684,50.0" style="fill:rgb(16.9%,51.4%,72.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (12640, 13352)
# ElementType: g3
# coding: False</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tb14df7d00fa2430a8200c99ba946cd91"><polygon points="210.22720454409088,100.0 249.659993199864,100.0 249.659993199864,50.0 210.22720454409088,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon
# interval: (13353, 16639)
# ElementType: g1
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tf2b03ff6a1a84f6ca5e1d70ad2a66561"><polygon points="249.6719934398688,100.0 250.7040140802816,100.0 250.7040140802816,50.0 249.6719934398688,50.0" style="fill:rgb(99.2%,68.2%,38%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: intron
# interval: (16640, 16726)
# ElementType: g2
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t4bfe95e8cfed48f985df77d4872840e3"><polygon points="250.71601432028638,100.0 253.27206544130883,100.0 253.27206544130883,50.0 250.71601432028638,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon
# interval: (16727, 16940)
# ElementType: g1
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tbfb5204d8a1e422a9fd1b4b8c97fe0c

# %% [markdown]
# ## Custom Chromosome
# Finally, you can define each part of your chromosome using the `custom` function. You will need to define the genomic elements that you will use to build your chromosome, and then specify where they occur along the chromosome. Remember to define your mutations first:

# %%
# "f" is fixed fitness effect (no distribution), so takes a single argument = fitness effect
mut1 = shadie.mtype(0.5, "f", 0.1)

# "g" is a gamma distribution and takes 2 arguments: alpha, beta
mut2 = shadie.mtype(0.1, "g", 0.3, 0.2)

# "n" is a normal distribution and takes 2 arguments: mean, standard deviation
mut3 = shadie.mtype(0.5, "n", 0.05, 0.1)

# "e" is a exponential distribution and takes 2 arguments: rate
mut4 = shadie.mtype(0.5, "e", -0.1)

# %% [markdown]
# This example uses a combination of custom mutations and default mutation types from shadie in the genomic elements:

# %%
e1 = shadie.etype([shadie.NEUT, shadie.DEL, shadie.BEN], (5,1,2), altname = "exon1")
e2 = shadie.etype([mut1, mut2, mut3], (5,1,2), altname = "exon2")
e3 = shadie.etype([mut1], (1,), altname = "exon3")
i1 = shadie.etype([mut4], (1,), altname = "intron1")
i2 = shadie.etype([mut4, shadie.DEL], (1,2), altname = "intron2")

# %%
custom = shadie.chromosome.explicit({
    (0, 1_200_000): shadie.NONCDS,
    (1_200_001, 1_400_000): i1,
    (1_400_001, 1_600_000): e1,
    (1_600_001, 1_800_000): i1,
    (1_800_001, 2_500_000): shadie.NONCDS,
    (2_500_001, 2_700_000): i1,
    (2_700_001, 2_900_000): e3,
    (2_900_001, 3_000_000): i1,
    (3_000_001, 3_700_000): e2,
    (3_700_001, 3_800_000): i1,
    (3_800_001, 5_000_000): shadie.NONCDS,
})

# %%
#exons will show up as different colors, 
#but all introns will show up green on the plot
custom.draw();
# Out:
# <div class="toyplot" id="t741259ba463b4bfe9d30c5952b4a81a2" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="700.0px" height="150.0px" viewBox="0 0 700.0 150.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="tb001e6601e5e4d9b90d698d1d8318277"><g class="toyplot-coordinates-Cartesian" id="tfb8f7378b4be4bec8e898d2bc9f37531"><clipPath id="t025fddf1b3e74855bfe2d1bd0dde05d3"><rect x="40.0" y="40.0" width="620.0" height="70.0"></rect></clipPath><g clip-path="url(#t025fddf1b3e74855bfe2d1bd0dde05d3)"><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="td5ef8b8af6994868b28133db6db0b1b6"><polygon points="50.0,100.0 194.0,100.0 194.0,50.0 50.0,50.0" style="fill:rgb(16.9%,51.4%,72.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (0, 1200000)
# ElementType: g3
# coding: False</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t3358b4fafdde422bafae52ae4b10740d"><polygon points="194.00011999999998,100.0 218.00000000000003,100.0 218.00000000000003,50.0 194.00011999999998,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: intron1
# interval: (1200001, 1400000)
# ElementType: g9
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="td54c242924bb4baf903a262aeb3253aa"><polygon points="218.00011999999998,100.0 242.0,100.0 242.0,50.0 218.00011999999998,50.0" style="fill:rgb(100%,100%,74.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon1
# interval: (1400001, 1600000)
# ElementType: g6
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tb33f094aae1f4da0b7e34c0d086a8c79"><polygon points="242.00012,100.0 266.0,100.0 266.0,50.0 242.00012,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: intron1
# interval: (1600001, 1800000)
# ElementType: g9
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="te046d3d0afc34f11822da6c994b44126"><polygon points="266.00012,100.0 350.0,100.0 350.0,50.0 266.00012,50.0" style="fill:rgb(16.9%,51.4%,72.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (1800001, 2500000)
# ElementType: g3
# coding: False</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tf14c98a3b2234a9d9bdaf8b5f4aa5de7"><polygon points="350.00012000000004,100.0 374.0,100.0 374.0,50.0 350.00012000000004,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: intron1
# interval: (2500001, 2700000)
# ElementType: g9
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t1d771fe1d89e4b1a9510d656be6225fb"><polygon points="374.00012000000004,100.0 398.0,100.0 398.0,50.0 374.00012000000004,50.0" style="fill:rgb(99.2%,68.2%,38%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon3
# interval: (2700001, 2900000)
# ElementType: g8
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t44bc179b4b3e4b2586a6c39fc63b889f"><polygon points="398.00012,100.0 410.0,100.0 410.0,50.0 398.00012,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: intron1
# interval: (2900001, 3000000)
# ElementType: g9
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tdf5dcda98182458c952a67058919f0b3"><polygon points="410.00012000000004,100.0 494.0,100.0 494.0,50.0 410.00012000000004,50.0" style="fill:rgb(84.3%,9.8%,11%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon2
# interval: (3000001, 3700000)
# ElementType: g7
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t734bcace5e0f461f97d509c03b8ca3d7"><polygon points="494.00012000000004,100.0 506.0,100.0 506.0,50.0 494.00012000000004,50.0" style="fill:rgb(67.1%,86.7%,64.3%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: intron1
# interval: (3700001, 3800000)
# ElementType: g9
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t482c02b139c64815be23abbaff67c733"><polygon points="506.00012000000004,100.0 650.0,100.0 650.0,50.0 506.00012000000004,50.0" style="fill:rgb(16.9%,51.4%,72.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (3800001, 5000000)
# ElementType: g3
# coding: False</title></polygon></g></g><g class="toyplot-coordinates-Axis" id="tbe18af1ce20e473a96c2fa7d411ab115" transform="translate(50.0,100.0)translate(0,10.0)"><line x1="0" y1="0" x2="600.0" y2="0" style=""></line><g><line x1="0.0" y1="0" x2="0.0" y2="-5" style=""></line><line x1="120.0" y1="0" x2="120.0" y2="-5" style=""></line><line x1="240.0" y1="0" x2="240.0" y2="-5" style=""></line><line x1="360.0" y1="0" x2="360.0" y2="-5" style=""></line><line x1="480.0" y1="0" x2="480.0" y2="-5" style=""></line><line x1="600.0" y1="0" x2="600.0" y2="-5" style=""></line></g><g><g transform="translate(0.0,6)"><text x="-2.78" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">0</text></g><g transform="translate(120.0,6)"><text x="-19.459999999999997" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">1000000</text></g><g transform="translate(240.0,6)"><text x="-19.459999999999997" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">2000000</text></g><g transform="translate(360.0,6)"><text x="-19.459999999999997" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">3000000</text></g><g transform="translate(480.0,6)"><text x="-19.459999999999997" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">4000000</text></g><g transform="translate(600.0,6)"><text x="-19.459999999999997" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">5000000</text></g></g><g class="toyplot-coordinates-Axis-coordinates" style="visibility:hidden" transform=""><line x1="0" x2="0" y1="-3.0" y2="4.5" style="stroke:rgb(43.9%,50.2%,56.5%);stroke-opacity:1.0;stroke-width:1.0"></line><text x="0" y="-6" style="alignment-baseline:alphabetic;fill:rgb(43.9%,50.2%,56.5%);fill-opacity:1.0;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle"></text></g></g></g></svg><div class="toyplot-behavior"><script>(function()
# {
# var modules={};
# modules["toyplot/tables"

# %% [markdown]
# You can also specify custom genomic elements using the random generator. The `intron`, `exon`, and `noncds` arguments will all accept a genomic element type object, or a list of multiple objects:

# %%
my_random_chrom = shadie.chromosome.random(genome_size = 100001,
                         intron = [i1, i2],
                         exon = [e1, e2, e3],
                         noncds_scale = 7000,
                         cds_scale = 3000,
                         intron_scale = 4000,
                         seed = 345,
                        )
my_random_chrom.draw();
# Out:
# <div class="toyplot" id="t0cc212813f5d4fb68e162fae525604c3" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="700.0px" height="150.0px" viewBox="0 0 700.0 150.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="tdc70cda4cc534478921481e1994da33c"><g class="toyplot-coordinates-Cartesian" id="tb07a4dbc67d14ad98edb92d4556a6057"><clipPath id="td4f8061c69a44148afecee2936f66528"><rect x="40.0" y="40.0" width="620.0" height="70.0"></rect></clipPath><g clip-path="url(#td4f8061c69a44148afecee2936f66528)"><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t90d5fada8925428d9bff239d80418c4f"><polygon points="50.0,100.0 77.5799543564573,100.0 77.5799543564573,50.0 50.0,50.0" style="fill:rgb(19.6%,53.3%,74.1%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (1, 4412)
# ElementType: g3
# coding: False</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t2dfc4d8a871f464b88dc239e82aebcdf"><polygon points="77.58620689655173,100.0 123.17972926501392,100.0 123.17972926501392,50.0 77.58620689655173,50.0" style="fill:rgb(60%,83.5%,58%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon3
# interval: (4413, 11705)
# ElementType: g8
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t1102495859204e3d902ccde40ddfbe47"><polygon points="123.18598180510833,100.0 123.41732578860163,100.0 123.41732578860163,50.0 123.18598180510833,50.0" style="fill:rgb(19.6%,53.3%,74.1%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (11706, 11743)
# ElementType: g3
# coding: False</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t3cd249f0556b4cf0b8949627c0e9c1ff"><polygon points="123.42357832869604,100.0 131.3580517085066,100.0 131.3580517085066,50.0 123.42357832869604,50.0" style="fill:rgb(60%,83.5%,58%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon3
# interval: (11744, 13013)
# ElementType: g8
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="ta106cf6130ca4c11af860d6e98eef194"><polygon points="131.364304248601,100.0 163.37730953199735,100.0 163.37730953199735,50.0 131.364304248601,50.0" style="fill:rgb(90.2%,96.1%,59.6%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: intron1
# interval: (13014, 18134)
# ElementType: g9
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t5775ab83dda84f3fa9ba56012b037374"><polygon points="163.3835620720918,100.0 165.0717478975834,100.0 165.0717478975834,50.0 163.3835620720918,50.0" style="fill:rgb(99.6%,87.8%,54.5%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon2
# interval: (18135, 18405)
# ElementType: g7
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t350c8005a3924a05b7add6b83691c44c"><polygon points="165.07800043767782,100.0 170.63025604151687,100.0 170.63025604151687,50.0 165.07800043767782,50.0" style="fill:rgb(98.8%,55.3%,34.9%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: intron2
# interval: (18406, 19294)
# ElementType: g10
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t08fd635ab3944c6db288e8ed0e77dee3"><polygon points="170.63650858161128,100.0 205.88832963391377,100.0 205.88832963391377,50.0 170.63650858161128,50.0" style="fill:rgb(60%,83.5%,58%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon3
# interval: (19295, 24933)
# ElementType: g8
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t244c03b8f9d34554a6bcc3fb758d5901"><polygon points="205.89458217400818,100.0 223.52049270015942,100.0 223.52049270015942,50.0 205.89458217400818,50.0" style="fill:rgb(19.6%,53.3%,74.1%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (24934, 27753)
# ElementType: g3
# coding: False</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="te73c8f1fdc9840fcbab01307adf767f3"><polygon points="223.52674524025383,100.0 236.4257354550286,100.0 236.4257354550286,50.0 223.52674524025383,50.0" style="fill:rgb(60%,83.5%,58%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon3
# interval: (27754, 29817)
# ElementType: g8
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t8e8653432f0049f0abc9cfbdd1a839d0"><polygon points="236.43198799512302,100.0 277.41113577390814,100.0 277.41113577390814,50.0 236.43198799512302,50.0" style="fill:rgb(19.6%,53.3%,74.1%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (29818, 36372)
# ElementType: g3
# coding: False</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t57a50a88f4994b58b773a6d03344b3f4"><polygon points="277.41738831400255,100.0 283.7074436489824,100.0 283.7074436489824,50.0 277.41738831400255,50.0" style="fill:rgb(83.5%,24.3%,31%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon1
# interval: (36373, 37379)
# ElementType: g6
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t25384459514c400bb19fb58e68b01653"><polygon points="283.7136961890768,100.0 296.78150498640076,100.0 296.78150498640076,50.0 283.7136961890768,50.0" style="fill:rgb(19.6%,53.3%,74.1%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (37380, 39470)
# ElementType: g3
# coding: False</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tdd798e1d0cd64263ac21876eb87df936"><polygon points="296.78775752649517,100.0 297.481789476975,100.0 297.481789476975,50.0 296.78775752649517,50.0" style="fill:rgb(60%,83.5%,58%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon3
# interval: (39471, 39582)
# ElementType: g8
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tbc7d9ca83e4f4d7e9bdf9b7de8f61d46"><polygon points="297.4880420170694,100.0 329.60108794197646,100.0 329.60108794197646,50.0 297.4880420170694,50.0" style="fill:rgb(19.6%,53.3%,74.1%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: noncds
# interval: (39583, 44719)
# ElementType: g3
# coding: False</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="tb3fd4693fedc46c9aafa566fc1d6f481"><polygon points="329.60734048207087,100.0 330.88285866133117,100.0 330.88285866133117,50.0 329.60734048207087,50.0" style="fill:rgb(83.5%,24.3%,31%);fill-opacity:1.0;opacity:0.75;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><title>name: exon1
# interval: (44720, 44924)
# ElementType: g6
# coding: True</title></polygon></g><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t37c7cbed880d4ede906

# %% [markdown]
# ## Interactive Plot
# You can visualize complex chromosomes using an interactive altair plot instead of the static toyplot by using the `inspect` function. For this feature to function properly, you *must* assign each of your genomic elements a unique `altname`. The altnames should contain `ex` and `int` to allow shadie to recognize them as either exons or introns. Otherwise, shadie will try to assign any non-neutral regions as exons and all neutral regions will be non-coding.
#
# Highlight areas on the lower plot to zoom in on the upper plot. Click anywhere on the lower plot to re-set the zoom. Hover over either plot for more information about each genomic element.
#
# *Note: this feature can be a little glitchy between altair updates.*

# %%
my_random_chrom.inspect()
# Out:
# alt.VConcatChart(...)
