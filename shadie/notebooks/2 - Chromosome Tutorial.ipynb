# %% [markdown]
# # Building a Chromosome for `shadie`

# %% [markdown]
# The simplest way to prepare a SLiM simulation using `shadie` is to let the `Chromosome` class automatically generate a single gene. The gene will consist of a single exon by default, although the user can also specify number of exons. The user can also supply a length (in base pairs) for the `genome_size` argument.

# %%
from shadie import Chromosome

# %%
#create Chromosome object. If no "genome" argument is supplied, the Chromosome class will generate a single gene
one_gene = Chromosome(genome_size = 2000)

# %%
#the Chromosome object can now be inspected using review() function
Chromosome.review(one_gene, item = "mutations")
Chromosome.review(one_gene, item = "eltypes")
Chromosome.review(one_gene, item = "elements")

#simpler syntax
one_gene.review("chromosome")

# %% [markdown]
# ## Random Chromosome
# You can also use the `Build` class of `shadie` to generate a random chromosome for you:

# %%
from shadie import Build
# Out:
# 2021-03-31 13:40:15.928 | WARNING  | shadie.mutations:__init__:82 - 'g', 'n', and 'w' distributions take 2 params
# 2021-03-31 13:40:15.928 | WARNING  | shadie.mutations:__init__:82 - 'g', 'n', and 'w' distributions take 2 params
# 2021-03-31 13:40:15.929 | WARNING  | shadie.mutations:__init__:74 - 'e' and 'f' distributions take 1 param
# 2021-03-31 13:40:15.929 | WARNING  | shadie.mutations:__init__:82 - 'g', 'n', and 'w' distributions take 2 params
# 2021-03-31 13:40:15.930 | DEBUG    | shadie.elements:__init__:76 - <MutationType: m2, 0.5, f, (0.0,)>
# 2021-03-31 13:40:15.930 | DEBUG    | shadie.elements:__init__:76 - <MutationType: m3, 0.1, g, (-0.03, 0.2)>
# 2021-03-31 13:40:15.931 | DEBUG    | shadie.elements:__init__:76 - <MutationType: m4, 0.8, e, (0.1,)>
# 2021-03-31 13:40:15.931 | DEBUG    | shadie.elements:__init__:76 - <MutationType: m2, 0.5, f, (0.0,)>
# 2021-03-31 13:40:15.931 | DEBUG    | shadie.elements:__init__:76 - <MutationType: m3, 0.1, g, (-0.03, 0.2)>
# 2021-03-31 13:40:15.932 | DEBUG    | shadie.elements:__init__:57 - frequencies: [1]
# 2021-03-31 13:40:15.932 | DEBUG    | shadie.elements:__init__:66 - mutation types: [<MutationType: m1, 0.5, f, (0.0,)>]
# 2021-03-31 13:40:15.933 | DEBUG    | shadie.elements:__init__:76 - <MutationType: m1, 0.5, f, (0.0,)>
# 2021-03-31 13:40:15.933 | DEBUG    | shadie.elements:__init__:76 - <MutationType: m2, 0.5, f, (0.0,)>
# 2021-03-31 13:40:15.934 | DEBUG    | shadie.elements:__init__:76 - <MutationType: m3, 0.1, g, (-0.03, 0.2)>
# 2021-03-31 13:40:15.934 | DEBUG    | shadie.elements:__init__:76 - <MutationType: m4, 0.8, e, (0.1,)>

# %%
#create a Build class object
random_chromosome = Build()

#run the random() function to generate the chromosome
Build.random(random_chromosome)
# Out:
# 2021-03-31 13:40:17.875 | DEBUG    | shadie.buildchromosome:random:149 - Made objects: base = {base}, genelements = {}, end = {end}
# 2021-03-31 13:40:17.880 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:17.885 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:17.908 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:17.927 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:17.936 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:17.972 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:17.979 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:17.986 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:17.991 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:17.999 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.003 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.025 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.038 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.063 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.080 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.084 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.096 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.110 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.116 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.128 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.145 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.158 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.167 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.172 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.185 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.222 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.232 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.256 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.302 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.309 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.321 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.326 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.333 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.341 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.356 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.361 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.371 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.384 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.406 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.411 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.413 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.427 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.433 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.459 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.466 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.482 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.499 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.522 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.533 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.546 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.556 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.562 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.571 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.578 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.585 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.623 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.636 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.647 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.669 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.673 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.688 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.707 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.712 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.761 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.764 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.779 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.806 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.813 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.816 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.843 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.850 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.866 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.873 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.919 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.929 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.946 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.949 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.953 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:18.962 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.000 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.003 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.017 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.035 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.047 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.069 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.076 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.114 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.118 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.126 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.145 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.160 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.169 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.174 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.178 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.186 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.195 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.197 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.202 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.215 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.228 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.244 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.252 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.264 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.272 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.278 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.282 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.291 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.301 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.306 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.319 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.323 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.329 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.334 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.350 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.354 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.359 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.365 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.386 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.405 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.422 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.434 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.437 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.475 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.494 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.497 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.500 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.509 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.514 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.524 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.529 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.551 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.559 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.570 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.576 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.587 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.596 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.608 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.611 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.619 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.640 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.645 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.650 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.652 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.658 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.666 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.670 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.680 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.698 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.709 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.712 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.719 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.726 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.738 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.750 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.752 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.765 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.773 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.778 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.787 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.791 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.800 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.809 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.829 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.833 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.853 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.860 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.873 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.879 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.887 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.905 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.908 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.917 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.923 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.931 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.944 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:19.972 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.002 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.004 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.034 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.043 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.067 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.098 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.146 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.151 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.154 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.160 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.163 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.181 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.189 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.208 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.219 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.229 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.234 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.247 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.254 | INFO     | shadie.buildchromosome:random:169 - Gene added
# 2021-03-31 13:40:20.278 | INFO     | shadie.buildchromosome:random:194 - Chromosome complete!
# 2021-03-31 13:40:20.279 | DEBUG    | shadie.buildchromosome:random:195 -               name    start   finish eltype  \
# 0        noncoding        0     3162     g3
# 3163          exon     3163     3489     g1
# 3490        intron     3490     4010     g2
# 4011          exon     4011     4315     g1
# 4316     noncoding     4316     5642     g3
# ...            ...      ...      ...    ...
# 999168      intron   999168   999621     g2
# 999622        exon   999622   999925     g1
# 999926      intron   999926  1000257     g2
# 1000258       exon  1000258  1000584     g1
# 1000585  noncoding  1000585   999999     g3
#
#                                                     script
# 0        <ElementType: g3, ['m1'], [1], mmJukesCantor(1...
# 3163     <ElementType: g1, ['m2', 'm3', 'm4'], [2, 8, 0...
# 3490     <ElementType: g2, ['m2', 'm3'], [9, 1], mmJuke...
# 4011     <ElementType: g1, ['m2', 'm3', 'm4'], [2, 8, 0...
# 4316     <ElementType: g3, ['m1'], [1], mmJukesCantor(1...
# ...                                                    ...
# 999168   <ElementType: g2, ['m2', 'm3'], [9, 1], mmJuke...
# 999622   <ElementType: g1, ['m2', 'm3', 'm4'], [2, 8, 0...
# 999926   <ElementType: g2, ['m2', 'm3'], [9, 1], mmJuke...
# 1000258  <ElementType: g1, ['m2', 'm3', 'm4'], [2, 8, 0...
# 1000585  <ElementType: g3, ['m1'], [1], mmJukesCantor(1...
#
# [1665 rows x 5 columns]

# %% [markdown]
# ### Pass Build object to Chromosome Class
# `random_chromsome` is a Build class object that can be assigned to `genome` argument in `Chromosome` class:

# %%
final_chromosome = Chromosome(genome = random_chromosome)
final_chromosome.review("elements")
# Out:
# Genomic Elements:
#               name    start   finish eltype  \
# 0        noncoding        0     3162     g3
# 3163          exon     3163     3489     g1
# 3490        intron     3490     4010     g2
# 4011          exon     4011     4315     g1
# 4316     noncoding     4316     5642     g3
# ...            ...      ...      ...    ...
# 999168      intron   999168   999621     g2
# 999622        exon   999622   999925     g1
# 999926      intron   999926  1000257     g2
# 1000258       exon  1000258  1000584     g1
# 1000585  noncoding  1000585   999999     g3
#
#                                                     script
# 0        <ElementType: g3, ['m1'], [1], mmJukesCantor(1...
# 3163     <ElementType: g1, ['m2', 'm3', 'm4'], [2, 8, 0...
# 3490     <ElementType: g2, ['m2', 'm3'], [9, 1], mmJuke...
# 4011     <ElementType: g1, ['m2', 'm3', 'm4'], [2, 8, 0...
# 4316     <ElementType: g3, ['m1'], [1], mmJukesCantor(1...
# ...                                                    ...
# 999168   <ElementType: g2, ['m2', 'm3'], [9, 1], mmJuke...
# 999622   <ElementType: g1, ['m2', 'm3', 'm4'], [2, 8, 0...
# 999926   <ElementType: g2, ['m2', 'm3'], [9, 1], mmJuke...
# 1000258  <ElementType: g1, ['m2', 'm3', 'm4'], [2, 8, 0...
# 1000585  <ElementType: g3, ['m1'], [1], mmJukesCantor(1...
#
# [1665 rows x 5 columns]

# %% [markdown]
# ### Interactive Plot
# You can use the `review()` function to generate an interactive plot to inspect your chromosome structure further. Draw a region on the bottom plot to view that region in the top plot.

# %%
final_chromosome.review("interactive")
# Out:
# Interactive altair chromosome map:
# <div id="altair-viz-ffbee636b8b94af48e37256fcbbbac54"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-ffbee636b8b94af48e37256fcbbbac54") {
#       outputDiv = document.getElementById("altair-viz-ffbee636b8b94af48e37256fcbbbac54");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "vconcat": [{"mark": "rect", "encoding": {"color": {"type": "nominal", "field": "Element Type", "scale": {"domain": ["exon", "intron", "noncoding"], "range": ["mediumvioletred", "lightgoldenrodyellow", "cornflowerblue"]}}, "tooltip": [{"type": "nominal", "field": "Element Type", "title": "Element Type"}, {"type": "quantitative", "field": "x1", "title": "Start"}, {"type": "quantitative", "field": "x2", "title": "Stop"}, {"type": "quantitative", "field": "length", "title": "Length"}], "x": {"type": "quantitative", "field": "x1", "scale": {"domain": {"selection": "selector001"}}, "title": null}, "x2": {"field": "x2"}, "y": {"type": "quantitative", "axis": null, "field": "y1"}, "y2": {"field": "y2"}}, "height": 80, "selection": {"selector001": {"type": "interval", "encodings": ["x"], "mark": {"fill": "red", "fillOpacity": 0.7}}}, "width": 850}, {"mark": "rect", "encoding": {"color": {"type": "nominal", "field": "Element Type", "scale": {"domain": ["exon", "intron", "noncoding"], "range": ["mediumvioletred", "lightgoldenrodyellow", "cornflowerblue"]}}, "tooltip": [{"type": "nominal", "field": "Element Type", "title": "Element Type"}, {"type": "quantitative", "field": "x1", "title": "Start"}, {"type": "quantitative", "field": "x2", "title": "Stop"}, {"type": "quantitative", "field": "length", "title": "Length"}], "x": {"type": "quantitative", "axis": {"title": "Base Pairs"}, "field": "x1"}, "x2": {"field": "x2"}, "y": {"type": "quantitative", "axis": null, "field": "y1"}, "y2": {"field": "y2"}}, "height": 40, "selection": {"selector001": {"type": "interval", "encodings": ["x"], "mark": {"fill": "red", "fillOpacity": 0.7}}}, "width": 850}], "data": {"name": "data-d773a75f20e1dd0abfcbbc55c98dee1a"}, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-d773a75f20e1dd0abfcbbc55c98dee1a": [{"Element Type": "noncoding", "x1": 0, "x2": 3162.0, "y1": 0, "y2": 1, "length": 3162.0}, {"Element Type": "exon", "x1": 3163, "x2": 3489.0, "y1": 0, "y2": 1, "length": 326.0}, {"Element Type": "intron", "x1": 3490, "x2": 4010.0, "y1": 0, "y2": 1, "length": 520.0}, {"Element Type": "exon", "x1": 4011, "x2": 4315.0, "y1": 0, "y2": 1, "length": 304.0}, {"Element Type": "noncoding", "x1": 4316, "x2": 5642.0, "y1": 0, "y2": 1, "length": 1326.0}, {"Element Type": "exon", "x1": 5643, "x2": 5897.0, "y1": 0, "y2": 1, "length": 254.0}, {"Element Type": "intron", "x1": 5898, "x2": 6243.0, "y1": 0, "y2": 1, "length": 345.0}, {"Element Type": "exon", "x1": 6244, "x2": 6503.0, "y1": 0, "y2": 1, "length": 259.0}, {"Element Type": "intron", "x1": 6504, "x2": 6893.0, "y1": 0, "y2": 1, "length": 389.0}, {"Element Type": "exon", "x1": 6894, "x2": 7043.0, "y1": 0, "y2": 1, "length": 149.0}, {"Element Type": "intron", "x1": 7044, "x2": 7636.0, "y1": 0, "y2": 1, "length": 592.0}, {"Element Type": "exon", "x1": 7637, "x2": 7862.0, "y1": 0, "y2": 1, "length": 225.0}, {"Element Type": "intron", "x1": 7863, "x2": 8293.0, "y1": 0, "y2": 1, "length": 430.0}, {"Element Type": "exon", "x1": 8294, "x2": 8588.0, "y1": 0, "y2": 1, "length": 294.0}, {"Element Type": "intron", "x1": 8589, "x2": 8875.0, "y1": 0, "y2": 1, "length": 286.0}, {"Element Type": "exon", "x1": 8876, "x2": 9191.0, "y1": 0, "y2": 1, "length": 315.0}, {"Element Type": "intron", "x1": 9192, "x2": 9908.0, "y1": 0, "y2": 1, "length": 716.0}, {"Element Type": "exon", "x1": 9909, "x2": 10252.0, "y1": 0, "y2": 1, "length": 343.0}, {"Element Type": "intron", "x1": 10253, "x2": 10730.0, "y1": 0, "y2": 1, "length": 477.0}, {"Element Type": "exon", "x1": 10731, "x2": 10980.0, "y1": 0, "y2": 1, "length": 249.0}, {"Element Type": "noncoding", "x1": 10981, "x2": 12462.0, "y1": 0, "y2": 1, "length": 1481.0}, {"Element Type": "exon", "x1": 12463, "x2": 12803.0, "y1": 0, "y2": 1, "length": 340.0}, {"Element Type": "intron", "x1": 12804, "x2": 13157.0, "y1": 0, "y2": 1, "length": 353.0}, {"Element Type": "exon", "x1": 13158 ...

# %% [markdown]
# ## Custom Chromosome
# Finally, you can define your own chromosome by providing a pandas dataframe that contains, at minimum, the `name` of the genomic element (as defined by you *or* using `shadie` defaults), the `start base` and the `end base`. Alternatively, you can provide the internal `idx` of the genomic element (in place of the `name`). You must provide a GenomeList class object and your genomic elements must be defined in the list.
