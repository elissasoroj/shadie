# %% [markdown]
# # Building a Chromosome for `shadie`

# %% [markdown]
# The simplest way to prepare a SLiM simulation using `shadie` is to let the `Chromosome` class automatically generate a single gene. The gene will consist of a single exon by default, although the user can also specify number of exons. The user can also supply a length (in base pairs) for the `genome_size` argument.

# %%
from shadie import Chromosome
# Out:
# 2021-04-02 12:56:55.206 | WARNING  | shadie.mutations:__init__:82 - 'g', 'n', and 'w' distributions take 2 params
# 2021-04-02 12:56:55.207 | WARNING  | shadie.mutations:__init__:82 - 'g', 'n', and 'w' distributions take 2 params
# 2021-04-02 12:56:55.207 | WARNING  | shadie.mutations:__init__:74 - 'e' and 'f' distributions take 1 param
# 2021-04-02 12:56:55.207 | WARNING  | shadie.mutations:__init__:82 - 'g', 'n', and 'w' distributions take 2 params
# 2021-04-02 12:56:55.208 | DEBUG    | shadie.elements:__init__:78 - <MutationType: m2, 0.5,f, (0.0,)>
# 2021-04-02 12:56:55.208 | DEBUG    | shadie.elements:__init__:78 - <MutationType: m3, 0.1,g, (-0.03, 0.2)>
# 2021-04-02 12:56:55.209 | DEBUG    | shadie.elements:__init__:78 - <MutationType: m4, 0.8,e, (0.1,)>
# 2021-04-02 12:56:55.209 | DEBUG    | shadie.elements:__init__:78 - <MutationType: m2, 0.5,f, (0.0,)>
# 2021-04-02 12:56:55.210 | DEBUG    | shadie.elements:__init__:78 - <MutationType: m3, 0.1,g, (-0.03, 0.2)>
# 2021-04-02 12:56:55.210 | DEBUG    | shadie.elements:__init__:59 - frequencies: [1]
# 2021-04-02 12:56:55.211 | DEBUG    | shadie.elements:__init__:68 - mutation types: [<MutationType: m1, 0.5,f, (0.0,)>]
# 2021-04-02 12:56:55.211 | DEBUG    | shadie.elements:__init__:78 - <MutationType: m1, 0.5,f, (0.0,)>
# 2021-04-02 12:56:55.212 | DEBUG    | shadie.elements:__init__:78 - <MutationType: m2, 0.5,f, (0.0,)>
# 2021-04-02 12:56:55.212 | DEBUG    | shadie.elements:__init__:78 - <MutationType: m3, 0.1,g, (-0.03, 0.2)>
# 2021-04-02 12:56:55.213 | DEBUG    | shadie.elements:__init__:78 - <MutationType: m4, 0.8,e, (0.1,)>

# %%
#create Chromosome object. If no "genome" argument is supplied, the Chromosome class will generate a single gene
one_gene = Chromosome(genome_size = 2000)

# %%
#the Chromosome object can now be inspected using review() function
Chromosome.review(one_gene, item = "mutations")
Chromosome.review(one_gene, item = "eltypes")
Chromosome.review(one_gene, item = "elements")

#simpler syntax
one_gene.review("chromosome")
# Out:
# Mutation Types:
#  <MutationList: ['m2', 'm3', 'm4']>
#
# Genomic Element Types:
#  <ElementList: ['g1']>
#
# Genomic Elements:
#    type  name  start  finish eltype  \
# 0  exon  exon      1    1999     g1
#
#                                               script
# 0  <ElementType: 'None', g1, ['m2', 'm3', 'm4'], ...
# Chromosome Summary
# # of Genes: 1
# Average # exons per gene: 1.0
# Average exon length: 1999.0 nt
# Average # introns per gene: 0.0
# Average introns length: 0 nt
#
# Static Chromosome Plot:
# <div class="toyplot" id="t0678022c0408461eb04c83f718272b90" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="3000.0px" height="200.0px" viewBox="0 0 3000.0 200.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t069efe3d84fe4a9485650befa2898192"><g class="toyplot-coordinates-Cartesian" id="tf344dd692b0c417d99156156793049b5"><clipPath id="t57d273c03a444a0f9a018c765992bab8"><rect x="40.0" y="40.0" width="2920.0" height="120.0"></rect></clipPath><g clip-path="url(#t57d273c03a444a0f9a018c765992bab8)"><g class="toyplot-mark-Range" style="stroke:none" id="t9ff44a39aa7f49fbbaacec16ca1c8170"><g class="toyplot-Series"><rect class="toyplot-Datum" x="51.45" y="50.0" width="2897.1000000000004" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g></g><g class="toyplot-coordinates-Axis" id="tc41cec88082c462bb6141860ed84e338" transform="translate(50.0,150.0)translate(0,10.0)"><line x1="1.45" y1="0" x2="2898.55" y2="0" style=""></line><g><g transform="translate(0.0,6)"><text x="-2.78" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">0</text></g><g transform="translate(725.0,6)"><text x="-8.34" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">500</text></g><g transform="translate(1450.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">1000</text></g><g transform="translate(2175.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">1500</text></g><g transform="translate(2900.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">2000</text></g></g><g class="toyplot-coordinates-Axis-coordinates" style="visibility:hidden" transform=""><line x1="0" x2="0" y1="-3.0" y2="4.5" style="stroke:rgb(43.9%,50.2%,56.5%);stroke-opacity:1.0;stroke-width:1.0"></line><text x="0" y="-6" style="alignment-baseline:alphabetic;fill:rgb(43.9%,50.2%,56.5%);fill-opacity:1.0;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle"></text></g></g><g class="toyplot-coordinates-Axis" id="t7d25ebbab240478b9dc283fc202a2983" transform="translate(50.0,150.0)rotate(-90.0)translate(0,-10.0)"><line x1="0" y1="0" x2="100.0" y2="0" style=""></line><g><g transform="translate(0.0,-6)"><text x="-6.95" y="-4.440892098500626e-16" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">0.0</text></g><g transform="translate(50.0,-6)"><text x="-6.95" y="-4.440892098500626e-16" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">0.5</text></g><g transform="translate(100.0,-6)"><text x="-6.95" y="-4.440892098500626e-16" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">1.0</text></g></g><g class="toyplot-coordinates-Axis-coordinates" style="visibility:hidden" tran ...
# {
# var modules={};
# modules["toyplot/canvas/id"] = "t069efe3d84fe4a9485650befa2898192";
# modules["toyplot/canvas"] = (function(canvas_id)
#     {
#         return document.querySelector("#" + canvas_id);
#     })(modules["toyplot/canvas/id"]);
# modules["toyplot.coordinates.Axis"] = (
#         function(canvas)
#         {
#             function sign(x)
#             {
#                 return x < 0 ? -1 : x > 0 ? 1 : 0;
#             }
#
#             function mix(a, b, amount)
#             {
#                 return ((1.0 - amount) * a) + (amount * b);
#             }
#
#             function log(x, base)
#             {
#                 return Math.log(Math.abs(x)) / Math.log(base);
#             }
#
#             function in_range(a, x, b)
#             {
#                 var left = Math.min(a, b);
#                 var right = Math.max(a, b);
#                 return left <= x && x <= right;
#             }
#
#             function inside(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.min, range, segment.range.max))
#                         return true;
#                 }
#                 return false;
#             }
#
#             function to_domain(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#                     {
#                         if(segment.scale == "linear")
#                         {
#                             var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#                             return mix(segment.domain.min, segment.domain.max, amount)
#                         }
#                         else if(segment.scale[0] == "log")
#                         {
#                             var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#                             var base = segment.scale[1];
#                             return sign(segment.domain.min) * Math.pow(base, mix(log(segment.domain.min, base), log(segment.domain.max, base), amount));
#                         }
#                     }
#                 }
#             }
#
#             var axes = {};
#
#             function display_coordinates(e)
#             {
#                 var current = canvas.createSVGPoint();
#                 current.x = e.clientX;
#                 current.y = e.clientY;
#
#                 for(var axis_id in axes)
#                 {
#                     var axis = document.querySelector("#" + axis_id);
#                     var coordinates = axis.querySelector(".toyplot-coordinates-Axis-coordinates");
#                     if(coordinates)
#                     {
#                         var projection = axes[axis_id];
#                         var local = current.matrixTransform(axis.getScreenCTM().inverse());
#                         if(inside(local.x, projection))
#                         {
#                             var domain = to_domain(local.x, projection);
#                             coordinates.style.visibility = "visible";
#                             coordinates.setAttribute("transform", "translate(" + local.x + ")");
#                             var text = coordinates.querySelector("text");
#                             text.textContent = domain.toFixed(2);
#                         }
#                         else
#                         {
#                             coordinates.style.visibility= "hidden";
#                         }

# %% [markdown]
# ## Random Chromosome
# You can also use the `Build` class of `shadie` to generate a random chromosome for you:

# %%
from shadie import Build

# %%
#create a Build class object
random_chromosome = Build()

#run the random() function to generate the chromosome
Build.random(random_chromosome)
# Out:
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:56 | INFO    | random          | Gene added
# 12:57 | INFO    | random          | Gene added
# 12:57 | INFO    | random          | Gene added
# 12:57 | INFO    | random          | Gene added
# 12:57 | INFO    | random          | Gene added
# 12:57 | INFO    | random          | Chromosome complete!

# %% [markdown]
# ### Pass Build object to Chromosome Class
# `random_chromsome` is a Build class object that can be assigned to `genome` argument in `Chromosome` class:

# %%
final_chromosome = Chromosome(genome = random_chromosome)
final_chromosome.review("elements")
# Out:
# Genomic Elements:
#               type name    start   finish eltype  \
# 0        noncoding  NaN        0     1001     g3
# 1002          exon  NaN     1002     1364     g1
# 1365        intron  NaN     1365     1850     g2
# 1851          exon  NaN     1851     2190     g1
# 2191        intron  NaN     2191     2647     g2
# ...            ...  ...      ...      ...    ...
# 995026      intron  NaN   995026   995491     g2
# 995492        exon  NaN   995492   995780     g1
# 995781   noncoding  NaN   995781  1000480     g3
# 1000481       exon  NaN  1000481  1000692     g1
# 1000693  noncoding  NaN  1000693   999999     g3
#
#                                                     script
# 0        <ElementType: 'None', g3, ['m1'], [1], mmJukes...
# 1002     <ElementType: 'None', g1, ['m2', 'm3', 'm4'], ...
# 1365     <ElementType: 'None', g2, ['m2', 'm3'], [9, 1]...
# 1851     <ElementType: 'None', g1, ['m2', 'm3', 'm4'], ...
# 2191     <ElementType: 'None', g2, ['m2', 'm3'], [9, 1]...
# ...                                                    ...
# 995026   <ElementType: 'None', g2, ['m2', 'm3'], [9, 1]...
# 995492   <ElementType: 'None', g1, ['m2', 'm3', 'm4'], ...
# 995781   <ElementType: 'None', g3, ['m1'], [1], mmJukes...
# 1000481  <ElementType: 'None', g1, ['m2', 'm3', 'm4'], ...
# 1000693  <ElementType: 'None', g3, ['m1'], [1], mmJukes...
#
# [1575 rows x 6 columns]

# %%
final_chromosome.review("chromosome")
# Out:
# Chromosome Summary
# # of Genes: 215
# Average # exons per gene: 3.702325581395349
# Average exon length: 264.2437185929648 nt
# Average # introns per gene: 2.702325581395349
# Average introns length: 450.01893287435456 nt
#
# Static Chromosome Plot:
# <div class="toyplot" id="tcd5d3afa57904835a1da2f721f7d5284" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="3000.0px" height="200.0px" viewBox="0 0 3000.0 200.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t5d8b33891772491eaa96c9eaaa3301a7"><g class="toyplot-coordinates-Cartesian" id="t26f03154ba454b26abff0d493b2a4f0f"><clipPath id="tf29229c66dc24075a3e6f7ac43712349"><rect x="40.0" y="40.0" width="2920.0" height="120.0"></rect></clipPath><g clip-path="url(#tf29229c66dc24075a3e6f7ac43712349)"><g class="toyplot-mark-Range" style="stroke:none" id="t89372d11660d45d7b421ea22b3035f8c"><g class="toyplot-Series"><rect class="toyplot-Datum" x="50.0" y="50.0" width="5.338900000000002" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="tbfab5afa3f314e4db0114074a893d14d"><g class="toyplot-Series"><rect class="toyplot-Datum" x="55.3418" y="50.0" width="0.658299999999997" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t77aec5efbf534a19a355fbe0c49ff65d"><g class="toyplot-Series"><rect class="toyplot-Datum" x="56.00299999999999" y="50.0" width="1.174500000000009" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t8c310f0c19684da68157533e2b1bac12"><g class="toyplot-Series"><rect class="toyplot-Datum" x="57.1804" y="50.0" width="0.6873000000000005" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="td1b62be35a1e493ab2f537c160802e0e"><g class="toyplot-Series"><rect class="toyplot-Datum" x="57.870599999999996" y="50.0" width="2.015500000000003" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="ta66656d42c09492498adcd32934c7eb0"><g class="toyplot-Series"><rect class="toyplot-Datum" x="59.888999999999996" y="50.0" width="0.8207000000000093" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="td57f6af4b7324c73af881751f42a7034"><g class="toyplot-Series"><rect class="toyplot-Datum" x="60.7126" y="50.0" width="1.6964999999999932" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t570d58f2ecdf423a9c4f1e5eacb6b8bb"><g class="toyplot-Series"><rect class="toyplot-Datum" x="62.412" y="50.0" width="0.585799999999999" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t298b012aa5174329a8523533c6ff19d4"><g class="toyplot-Series"><rect class="toyplot-Datum" x="63.000699999999995" y="50.0" width="1.3282000000000096" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t6fb29193b6d24dd39e14d0f3fd5f540c"><g class="toyplot-Series"><rect class="toyplot-Datum" x="64.3318" y="50.0" width="0.620599999999996" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t8bd1248ca9a746ebbd4c51e0839042b9"><g class="toyplot-Series"><rect cl ...

# %% [markdown]
# ### Interactive Plot
# You can use the `review()` function to generate an interactive plot to inspect your chromosome structure further. Draw a region on the bottom plot to view that region in the top plot.

# %%
final_chromosome.review("interactive")
# Out:
# Interactive altair chromosome map:
# <div id="altair-viz-cf0ec673f9724163a5045c94bf4edf33"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-cf0ec673f9724163a5045c94bf4edf33") {
#       outputDiv = document.getElementById("altair-viz-cf0ec673f9724163a5045c94bf4edf33");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "vconcat": [{"mark": "rect", "encoding": {"color": {"type": "nominal", "field": "altname", "scale": {"domain": ["exon", "intron", "noncoding"], "range": ["mediumvioletred", "lightgoldenrodyellow", "cornflowerblue"]}}, "tooltip": [{"type": "nominal", "field": "type", "title": "Element Type"}, {"type": "nominal", "field": "altname", "title": "Name"}, {"type": "quantitative", "field": "length", "title": "Length"}, {"type": "quantitative", "field": "x1", "title": "Start"}, {"type": "quantitative", "field": "x2", "title": "Stop"}], "x": {"type": "quantitative", "field": "x1", "scale": {"domain": {"selection": "selector001"}}, "title": null}, "x2": {"field": "x2"}, "y": {"type": "quantitative", "axis": null, "field": "y1"}, "y2": {"field": "y2"}}, "height": 80, "selection": {"selector001": {"type": "interval", "encodings": ["x"], "mark": {"fill": "red", "fillOpacity": 0.7}}}, "width": 850}, {"mark": "rect", "encoding": {"color": {"type": "nominal", "field": "altname", "scale": {"domain": ["exon", "intron", "noncoding"], "range": ["mediumvioletred", "lightgoldenrodyellow", "cornflowerblue"]}}, "tooltip": [{"type": "nominal", "field": "type", "title": "Element Type"}, {"type": "nominal", "field": "altname", "title": "Name"}, {"type": "quantitative", "field": "length", "title": "Length"}, {"type": "quantitative", "field": "x1", "title": "Start"}, {"type": "quantitative", "field": "x2", "title": "Stop"}], "x": {"type": "quantitative", "axis": {"title": "Base Pairs"}, "field": "x1"}, "x2": {"field": "x2"}, "y": {"type": "quantitative", "axis": null, "field": "y1"}, "y2": {"field": "y2"}}, "height": 40, "selection": {"selector001": {"type": "interval", "encodings": ["x"], "mark": {"fill": "red", "fillOpacity": 0.7}}}, "width": 850}], "data": {"name": "data-7a32774b890fbe144cc7fed038912cdc"}, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-7a32774b890fbe144cc7fed038912cdc": [{"type": "noncoding", "altname": "noncoding", "x1": 0, "x2": 1001.0, "y1": 0, "y2": 1, "length": 1001.0}, {"type": "exon", "altname": "exon", "x1": 1002, "x2": 1364.0, "y1": 0, "y2": 1, "length": 362.0}, {"type": "intron", "altname": "intron", "x1": 1365, "x2": 1850.0, "y1": 0, "y2": 1, "length": 485.0}, {"type": "exon", "altname": "exon", "x1": 1851, "x2": 2190.0, "y1": 0, "y2": 1, "length": 339.0}, {"type": "intron", "altname": "intron", "x1": 2191, "x2": 2647.0, "y1": 0, "y2": 1, "length": 456.0}, {"type": "exon", "altname": "exon", "x1": 2648, "x2": 2902.0, "y1": 0, "y2": 1, "length": 254.0}, {"type": "noncoding", "altname": "noncoding", "x1": 2903, "x2": 4236.0, "y1": 0, "y2": 1, "length": 1333.0}, {"type": "exon", "altname": "exon", "x1": 4237, "x2": 4454.0, "y1": 0, "y2": 1, "length": 217.0}, {"type": "intron", "altname": "intron", "x1": 4455, "x2": 5044.0, "y1": 0, "y2": 1, "length": 589.0}, {"type": "exon", "altname": "exon", "x1": 5045, "x2": 5335.0, "y1": 0, "y2": 1, "length": 290.0}, {"type": "intron", "altname": "intron", "x1": 5336, "x2": 5733.0, "y1": 0, "y2": 1, "length": 397.0}, {"type": "exon", "altname": "exon", "x1": 5734, "x2": 5902.0, "y1": 0, "y2": 1, "length": 168.0}, {"type": "intron", "altname": "intron", "x1": 5903, "x2": 6429.0, "y1": 0, "y2": 1, "length": 526.0}, {"type": "exon", "altname": "exon", "x1": 6430, "x2": 6686.0, "y1": 0, "y2": 1, "length": 256.0}, {"type": "noncoding", "altname": "noncoding", "x1": 6687, "x2": 7025.0, "y1": 0, "y2": 1, "length": 338.0}, {"type": "exon", "altname": "exon", "x1": 7026, "x2": 7192.0, "y1": 0, "y2": 1, "length": 166.0}, {"type": "intron", "altname": "intron", "x1": 7193, "x2": 7746.0, "y1": 0, "y2": 1, "length": 553.0}, {"type": "exon", "altname": "exon", "x1": 7747, "x2": 8019.0, "y1": 0, "y2": 1, "length": 272.0}, {"type": "intron", "altname": "intron", "x1": 8020, "x2": 8562.0, "y1": 0, "y2": 1, "length": 542.0}, {"type": "exon", "altname": "exon", "x1": 8563, "x2": 8721.0, "y1": 0, " ...

# %% [markdown]
# ## Random Chromosome with Custom Mutation Types & Genomic Element Types

# %%
from shadie import ElementList
from shadie import ElementType
from shadie import MutationType
from shadie import MutationList

#create your custom mutation types and save to a MutationList
mut1 = MutationType(0.5, "f", 0)
mut2 = MutationType(0.5, "e", 0.4)
mut3 = MutationType(0.5, "n", 0.4, .1)
mut4 = MutationType(0.5, "w", 0.3, 0.2)
mut5 = MutationType(0.5, "g", -0.4, .1)

mutlist = MutationList(mut1, mut2, mut3, mut4, mut5)

#create your custom genomic element types and save to an ElementList
noncod = ElementType(mut1, 1, altname = "nc")
exon1 = ElementType([mut2, mut5], [1, 1], altname = "ex1")
exon2 = ElementType([mut2, mut3, mut4], [9, 1, .02], altname = "ex2")
intron1 = ElementType([mut2, mut5], [1, 1], altname = "int1")
intron2 = ElementType([mut2, mut5], [1, 1], altname = "int2")

mycustomlist = ElementList(mutlist, noncod, exon1, exon2, intron1, intron2)
# Out:
# 12:46 | WARNING | __init__        | 'g', 'n', and 'w' distributions take 2 params
# 12:46 | WARNING | __init__        | 'g', 'n', and 'w' distributions take 2 params
# 12:46 | WARNING | __init__        | 'e' and 'f' distributions take 1 param
# 12:46 | WARNING | __init__        | 'e' and 'f' distributions take 1 param
# 12:46 | WARNING | __init__        | 'e' and 'f' distributions take 1 param

# %%
from shadie import Build

#initialize the Build class object
custom_build = Build(
    exons = [exon1, exon2], 
    introns = [intron1, intron2], 
    noncoding = [noncod], 
    elementlist = mycustomlist)

# %%
#run the same random function
custom_build.random()
# Out:
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Gene added
# 12:46 | INFO    | random          | Chromosome complete!

# %%
from shadie import Chromosome

customized_chrom = Chromosome(genome = custom_build)

# %%
customized_chrom.review("elements")
# Out:
# Genomic Elements:
#         name   start  finish eltype  \
# 0         nc       0    2261     g5
# 2262     ex2    2262    2476     g7
# 2477      nc    2477    5056     g5
# 5057     ex1    5057    5257     g6
# 5258    int2    5258    5741     g9
# ...      ...     ...     ...    ...
# 994934  int1  994934  995290     g8
# 995291   ex2  995291  995661     g7
# 995662  int2  995662  996122     g9
# 996123   ex1  996123  996369     g6
# 996370    nc  996370  999999     g5
#
#                                                    script       type
# 0                'g5', c(m5),c(1), mmJukesCantor(1e-06/3)  noncoding
# 2262    'g7', c(m6, m7, m8),c(9, 1, 0.02), mmJukesCant...       exon
# 2477             'g5', c(m5),c(1), mmJukesCantor(1e-06/3)  noncoding
# 5057      'g6', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)       exon
# 5258      'g9', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)     intron
# ...                                                   ...        ...
# 994934    'g8', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)     intron
# 995291  'g7', c(m6, m7, m8),c(9, 1, 0.02), mmJukesCant...       exon
# 995662    'g9', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)     intron
# 996123    'g6', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)       exon
# 996370           'g5', c(m5),c(1), mmJukesCantor(1e-06/3)  noncoding
#
# [1695 rows x 6 columns]

# %%
import pandas as pd
final_chromosome.genome["name"]

for index, row in final_chromosome.genome.iterrows():
    if pd.isna(row['name']):
        print(row['type'])
    else: 
        print(row['name'])
# Out:
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding

# %%
customized_chrom.review("chromosome")
# Out:
# Chromosome Summary
# # of Genes: 186
# Average # exons per gene: 4.553763440860215
# Average exon length: 261.16056670602126 nt
# Average # introns per gene: 3.553763440860215
# Average introns length: 449.0574886535552 nt
#
# Static Chromosome Plot:
# <div class="toyplot" id="tf77bfaa1e6e44a4f9424b6dceb65ceac" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="3000.0px" height="200.0px" viewBox="0 0 3000.0 200.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t8aabbb5c6e0b4f9a84c66fd009b3d1ea"><g class="toyplot-coordinates-Cartesian" id="ted15a07edac74528a00cc66590f5992e"><clipPath id="tce67ed4325064b2b85ae2c3b2f53b8c4"><rect x="40.0" y="40.0" width="2920.0" height="120.0"></rect></clipPath><g clip-path="url(#tce67ed4325064b2b85ae2c3b2f53b8c4)"><g class="toyplot-mark-Range" style="stroke:none" id="tb71cb28a320e454c92edbc13c801e822"><g class="toyplot-Series"><rect class="toyplot-Datum" x="50.0" y="50.0" width="6.556899999999999" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t5fb12faba6104518b654b90af82752e0"><g class="toyplot-Series"><rect class="toyplot-Datum" x="56.559799999999996" y="50.0" width="0.6206000000000031" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t9f3642f082604beabf32c4c906a201d4"><g class="toyplot-Series"><rect class="toyplot-Datum" x="57.1833" y="50.0" width="7.479099999999988" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t5a41cf56d58548f18e05d70aa3bab57c"><g class="toyplot-Series"><rect class="toyplot-Datum" x="64.6653" y="50.0" width="0.5799999999999983" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="ta81e87d74986457fa583263984f9892b"><g class="toyplot-Series"><rect class="toyplot-Datum" x="65.2482" y="50.0" width="1.4007000000000005" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t88e8a08301e342ddba935899a30d7f08"><g class="toyplot-Series"><rect class="toyplot-Datum" x="66.6518" y="50.0" width="0.7395000000000067" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t8ebbf6d54d384065867b2464c1516150"><g class="toyplot-Series"><rect class="toyplot-Datum" x="67.39420000000001" y="50.0" width="1.699399999999983" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t3016e075fa9e4e91abec9a69b0762df7"><g class="toyplot-Series"><rect class="toyplot-Datum" x="69.0965" y="50.0" width="0.6089999999999947" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="tf7b76445fc7d48a6a9289ce566472e39"><g class="toyplot-Series"><rect class="toyplot-Datum" x="69.7084" y="50.0" width="1.502200000000002" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t049ad202269844a58fad1991ce56a143"><g class="toyplot-Series"><rect class="toyplot-Datum" x="71.21350000000001" y="50.0" width="0.5074999999999932" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t449fdc847d50431fa5546ae3de624746"><g class="toyplot-Series"><rect class=" ...

# %%
customized_chrom.review("interactive")
# Out:
# Interactive altair chromosome map:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-2aa577879e52> in <module>
# ----> 1 customized_chrom.review("interactive")
#
# ~/code/git/hacks/shadie/shadie/chromosome.py in review(self, item)
#     190             for index, row in self.genome.iterrows():
#     191                 eltype.append(row['type'])
# --> 192                 if self.genome.loc['name'].isnull():
#     193                     altname.append(row['type'])
#     194                 else:
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3491             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3492         else:
# -> 3493             loc = self.index.get_loc(key)
#    3494
#    3495             if isinstance(loc, np.ndarray):
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'name'

# %% [markdown]
# ## Custom Chromosome
# Finally, you can define your own chromosome by providing a pandas dataframe that contains, at minimum, the `name` of the genomic element (as defined by you *or* using `shadie` defaults), the `start base` and the `end base`. Alternatively, you can provide the internal `idx` of the genomic element (in place of the `name`). You must provide a GenomeList class object and your genomic elements must be defined in the list.
