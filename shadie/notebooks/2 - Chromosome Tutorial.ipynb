# %% [markdown]
# # Building a Chromosome for `shadie`

# %% [markdown]
# The simplest way to prepare a SLiM simulation using `shadie` is to let the `Chromosome` class automatically generate a single gene. The gene will consist of a single exon by default, although the user can also specify number of exons. The user can also supply a length (in base pairs) for the `genome_size` argument.

# %%
from shadie import Chromosome

# %%
#create Chromosome object. If no "genome" argument is supplied, the Chromosome class will generate a single gene
one_gene = Chromosome(genome_size = 2000)

# %%
#the Chromosome object can now be inspected using review() function
Chromosome.review(one_gene, item = "mutations")
Chromosome.review(one_gene, item = "eltypes")
Chromosome.review(one_gene, item = "elements")

#simpler syntax
one_gene.review("chromosome")
# Out:
# Mutation Types:
#  <MutationList: ['m2', 'm3', 'm4']>
#
# Genomic Element Types:
#  <ElementList: ['g1']>
#
# Genomic Elements:
#    type  name  start  finish eltype  \
# 0  exon  exon      1    1999     g1
#
#                                               script
# 0  <ElementType: 'None', g1, ['m2', 'm3', 'm4'], ...
# Chromosome Summary
# # of Genes: 1
# Average # exons per gene: 1.0
# Average exon length: 1999.0 nt
# Average # introns per gene: 0.0
# Average introns length: 0 nt
#
# Static Chromosome Plot:
# <div class="toyplot" id="t425c6019ad40469d8ff738d0573b2c63" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="3000.0px" height="200.0px" viewBox="0 0 3000.0 200.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="te8cecd7d12e84246ba50dd2b74769132"><g class="toyplot-coordinates-Cartesian" id="tce8e611065394ca9bc5156983e5adf64"><clipPath id="t7a3beb9f73ff45b48db7b46b535470d0"><rect x="40.0" y="40.0" width="2920.0" height="120.0"></rect></clipPath><g clip-path="url(#t7a3beb9f73ff45b48db7b46b535470d0)"><g class="toyplot-mark-Range" style="stroke:none" id="t61a12722167c422ab12971c0d0281bed"><g class="toyplot-Series"><rect class="toyplot-Datum" x="51.45" y="50.0" width="2897.1000000000004" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g></g><g class="toyplot-coordinates-Axis" id="t1d93b9f3bccd487bba209f4a56f2dece" transform="translate(50.0,150.0)translate(0,10.0)"><line x1="1.45" y1="0" x2="2898.55" y2="0" style=""></line><g><g transform="translate(0.0,6)"><text x="-2.78" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">0</text></g><g transform="translate(725.0,6)"><text x="-8.34" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">500</text></g><g transform="translate(1450.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">1000</text></g><g transform="translate(2175.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">1500</text></g><g transform="translate(2900.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">2000</text></g></g><g class="toyplot-coordinates-Axis-coordinates" style="visibility:hidden" transform=""><line x1="0" x2="0" y1="-3.0" y2="4.5" style="stroke:rgb(43.9%,50.2%,56.5%);stroke-opacity:1.0;stroke-width:1.0"></line><text x="0" y="-6" style="alignment-baseline:alphabetic;fill:rgb(43.9%,50.2%,56.5%);fill-opacity:1.0;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle"></text></g></g><g class="toyplot-coordinates-Axis" id="tce872ff1d02d47099ea3d57dde6637ed" transform="translate(50.0,150.0)rotate(-90.0)translate(0,-10.0)"><line x1="0" y1="0" x2="100.0" y2="0" style=""></line><g><g transform="translate(0.0,-6)"><text x="-6.95" y="-4.440892098500626e-16" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">0.0</text></g><g transform="translate(50.0,-6)"><text x="-6.95" y="-4.440892098500626e-16" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">0.5</text></g><g transform="translate(100.0,-6)"><text x="-6.95" y="-4.440892098500626e-16" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">1.0</text></g></g><g class="toyplot-coordinates-Axis-coordinates" style="visibility:hidden" tran ...
# {
# var modules={};
# modules["toyplot/canvas/id"] = "te8cecd7d12e84246ba50dd2b74769132";
# modules["toyplot/canvas"] = (function(canvas_id)
#     {
#         return document.querySelector("#" + canvas_id);
#     })(modules["toyplot/canvas/id"]);
# modules["toyplot.coordinates.Axis"] = (
#         function(canvas)
#         {
#             function sign(x)
#             {
#                 return x < 0 ? -1 : x > 0 ? 1 : 0;
#             }
#
#             function mix(a, b, amount)
#             {
#                 return ((1.0 - amount) * a) + (amount * b);
#             }
#
#             function log(x, base)
#             {
#                 return Math.log(Math.abs(x)) / Math.log(base);
#             }
#
#             function in_range(a, x, b)
#             {
#                 var left = Math.min(a, b);
#                 var right = Math.max(a, b);
#                 return left <= x && x <= right;
#             }
#
#             function inside(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.min, range, segment.range.max))
#                         return true;
#                 }
#                 return false;
#             }
#
#             function to_domain(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#                     {
#                         if(segment.scale == "linear")
#                         {
#                             var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#                             return mix(segment.domain.min, segment.domain.max, amount)
#                         }
#                         else if(segment.scale[0] == "log")
#                         {
#                             var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#                             var base = segment.scale[1];
#                             return sign(segment.domain.min) * Math.pow(base, mix(log(segment.domain.min, base), log(segment.domain.max, base), amount));
#                         }
#                     }
#                 }
#             }
#
#             var axes = {};
#
#             function display_coordinates(e)
#             {
#                 var current = canvas.createSVGPoint();
#                 current.x = e.clientX;
#                 current.y = e.clientY;
#
#                 for(var axis_id in axes)
#                 {
#                     var axis = document.querySelector("#" + axis_id);
#                     var coordinates = axis.querySelector(".toyplot-coordinates-Axis-coordinates");
#                     if(coordinates)
#                     {
#                         var projection = axes[axis_id];
#                         var local = current.matrixTransform(axis.getScreenCTM().inverse());
#                         if(inside(local.x, projection))
#                         {
#                             var domain = to_domain(local.x, projection);
#                             coordinates.style.visibility = "visible";
#                             coordinates.setAttribute("transform", "translate(" + local.x + ")");
#                             var text = coordinates.querySelector("text");
#                             text.textContent = domain.toFixed(2);
#                         }
#                         else
#                         {
#                             coordinates.style.visibility= "hidden";
#                         }

# %% [markdown]
# ## Random Chromosome
# You can also use the `Build` class of `shadie` to generate a random chromosome for you:

# %%
from shadie import Build

# %%
#create a Build class object
random_chromosome = Build()

#run the random() function to generate the chromosome
Build.random(random_chromosome)
# Out:
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Chromosome complete!

# %%
print(random_chromosome.mutationlist)
# Out:
# <MutationList: ['m1', 'm2', 'm3', 'm4']>

# %% [markdown]
# ### Pass Build object to Chromosome Class
# `random_chromsome` is a Build class object that can be assigned to `genome` argument in `Chromosome` class:

# %%
final_chromosome = Chromosome(genome = random_chromosome)
final_chromosome.review("elements")
# Out:
# Genomic Elements:
#              type name   start  finish eltype  \
# 0       noncoding  NaN       0     476     g3
# 477          exon  NaN     477     706     g1
# 707        intron  NaN     707    1100     g2
# 1101         exon  NaN    1101    1412     g1
# 1413    noncoding  NaN    1413    2048     g3
# ...           ...  ...     ...     ...    ...
# 997353     intron  NaN  997353  997964     g2
# 997965       exon  NaN  997965  998198     g1
# 998199     intron  NaN  998199  998623     g2
# 998624       exon  NaN  998624  998911     g1
# 998912  noncoding  NaN  998912  999999     g3
#
#                                                    script
# 0       <ElementType: 'None', g3, ['m1'], [1], mmJukes...
# 477     <ElementType: 'None', g1, ['m2', 'm3', 'm4'], ...
# 707     <ElementType: 'None', g2, ['m2', 'm3'], [9, 1]...
# 1101    <ElementType: 'None', g1, ['m2', 'm3', 'm4'], ...
# 1413    <ElementType: 'None', g3, ['m1'], [1], mmJukes...
# ...                                                   ...
# 997353  <ElementType: 'None', g2, ['m2', 'm3'], [9, 1]...
# 997965  <ElementType: 'None', g1, ['m2', 'm3', 'm4'], ...
# 998199  <ElementType: 'None', g2, ['m2', 'm3'], [9, 1]...
# 998624  <ElementType: 'None', g1, ['m2', 'm3', 'm4'], ...
# 998912  <ElementType: 'None', g3, ['m1'], [1], mmJukes...
#
# [1649 rows x 6 columns]

# %%
final_chromosome.review("chromosome")
# Out:
# Chromosome Summary
# # of Genes: 204
# Average # exons per gene: 4.03921568627451
# Average exon length: 262.7342233009709 nt
# Average # introns per gene: 3.0392156862745097
# Average introns length: 453.6516129032258 nt
#
# Static Chromosome Plot:
# <div class="toyplot" id="t74f04c30cb6845dc90fbf0661d08f331" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="3000.0px" height="200.0px" viewBox="0 0 3000.0 200.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="td8cfc3dcebb942ebaff647c1467eb142"><g class="toyplot-coordinates-Cartesian" id="t91e7cc1b8dba4223ba0fc96abb7d885e"><clipPath id="t88457ae5812b416ca7a72a24974ec945"><rect x="40.0" y="40.0" width="2920.0" height="120.0"></rect></clipPath><g clip-path="url(#t88457ae5812b416ca7a72a24974ec945)"><g class="toyplot-mark-Range" style="stroke:none" id="tb4fd79b357644fb18d0784ce43409d24"><g class="toyplot-Series"><rect class="toyplot-Datum" x="50.0" y="50.0" width="1.3804000000000016" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t57fec0bdb7d04075a565c0bed2b7b3d4"><g class="toyplot-Series"><rect class="toyplot-Datum" x="51.383300000000006" y="50.0" width="0.6640999999999977" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t5eaa7a8fdc024a85a7d37c6c09411186"><g class="toyplot-Series"><rect class="toyplot-Datum" x="52.0503" y="50.0" width="1.1396999999999977" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t0841392f8029480c8f94ef39cb516d7f"><g class="toyplot-Series"><rect class="toyplot-Datum" x="53.1929" y="50.0" width="0.9018999999999977" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="tea535a71a13640239765ed6893518981"><g class="toyplot-Series"><rect class="toyplot-Datum" x="54.0977" y="50.0" width="1.8414999999999964" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="tcbee5bb07a6f4670aecb5ff07e163046"><g class="toyplot-Series"><rect class="toyplot-Datum" x="55.9421" y="50.0" width="0.548099999999998" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t59a9b10d3ca14bf3ae9c5c5bd48c6078"><g class="toyplot-Series"><rect class="toyplot-Datum" x="56.4931" y="50.0" width="9.6918" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="tf61a916cf80145969e97449185184d48"><g class="toyplot-Series"><rect class="toyplot-Datum" x="66.1878" y="50.0" width="0.7134000000000071" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t6eb1dd08308642fe86b4e9b3c4879a84"><g class="toyplot-Series"><rect class="toyplot-Datum" x="66.9041" y="50.0" width="1.191900000000004" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t69af7ba3c26c4edf825f3d308474c7e3"><g class="toyplot-Series"><rect class="toyplot-Datum" x="68.0989" y="50.0" width="0.7220999999999975" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="tca3174bc71dc4016b17a1240b94ac05b"><g class="toyplot-Series"><rect class="toyplot-Datum" x="68.8239" ...

# %% [markdown]
# ### Interactive Plot
# You can use the `review()` function to generate an interactive plot to inspect your chromosome structure further. Draw a region on the bottom plot to view that region in the top plot.

# %%
final_chromosome.review("interactive")
# Out:
# Interactive altair chromosome map:
# <div id="altair-viz-607c75d4bc2340528b73da4a96a39932"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-607c75d4bc2340528b73da4a96a39932") {
#       outputDiv = document.getElementById("altair-viz-607c75d4bc2340528b73da4a96a39932");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "vconcat": [{"mark": "rect", "encoding": {"color": {"type": "nominal", "field": "altname", "scale": {"domain": ["exon", "intron", "noncoding"], "range": ["mediumvioletred", "lightgoldenrodyellow", "cornflowerblue"]}}, "tooltip": [{"type": "nominal", "field": "type", "title": "Element Type"}, {"type": "nominal", "field": "altname", "title": "Name"}, {"type": "quantitative", "field": "length", "title": "Length"}, {"type": "quantitative", "field": "x1", "title": "Start"}, {"type": "quantitative", "field": "x2", "title": "Stop"}], "x": {"type": "quantitative", "field": "x1", "scale": {"domain": {"selection": "selector001"}}, "title": null}, "x2": {"field": "x2"}, "y": {"type": "quantitative", "axis": null, "field": "y1"}, "y2": {"field": "y2"}}, "height": 80, "selection": {"selector001": {"type": "interval", "encodings": ["x"], "mark": {"fill": "red", "fillOpacity": 0.7}}}, "width": 850}, {"mark": "rect", "encoding": {"color": {"type": "nominal", "field": "altname", "scale": {"domain": ["exon", "intron", "noncoding"], "range": ["mediumvioletred", "lightgoldenrodyellow", "cornflowerblue"]}}, "tooltip": [{"type": "nominal", "field": "type", "title": "Element Type"}, {"type": "nominal", "field": "altname", "title": "Name"}, {"type": "quantitative", "field": "length", "title": "Length"}, {"type": "quantitative", "field": "x1", "title": "Start"}, {"type": "quantitative", "field": "x2", "title": "Stop"}], "x": {"type": "quantitative", "axis": {"title": "Base Pairs"}, "field": "x1"}, "x2": {"field": "x2"}, "y": {"type": "quantitative", "axis": null, "field": "y1"}, "y2": {"field": "y2"}}, "height": 40, "selection": {"selector001": {"type": "interval", "encodings": ["x"], "mark": {"fill": "red", "fillOpacity": 0.7}}}, "width": 850}], "data": {"name": "data-c379d68a62be3a3b599f89b2e5996ffe"}, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-c379d68a62be3a3b599f89b2e5996ffe": [{"type": "noncoding", "altname": "noncoding", "x1": 0, "x2": 476.0, "y1": 0, "y2": 1, "length": 476.0}, {"type": "exon", "altname": "exon", "x1": 477, "x2": 706.0, "y1": 0, "y2": 1, "length": 229.0}, {"type": "intron", "altname": "intron", "x1": 707, "x2": 1100.0, "y1": 0, "y2": 1, "length": 393.0}, {"type": "exon", "altname": "exon", "x1": 1101, "x2": 1412.0, "y1": 0, "y2": 1, "length": 311.0}, {"type": "noncoding", "altname": "noncoding", "x1": 1413, "x2": 2048.0, "y1": 0, "y2": 1, "length": 635.0}, {"type": "exon", "altname": "exon", "x1": 2049, "x2": 2238.0, "y1": 0, "y2": 1, "length": 189.0}, {"type": "noncoding", "altname": "noncoding", "x1": 2239, "x2": 5581.0, "y1": 0, "y2": 1, "length": 3342.0}, {"type": "exon", "altname": "exon", "x1": 5582, "x2": 5828.0, "y1": 0, "y2": 1, "length": 246.0}, {"type": "intron", "altname": "intron", "x1": 5829, "x2": 6240.0, "y1": 0, "y2": 1, "length": 411.0}, {"type": "exon", "altname": "exon", "x1": 6241, "x2": 6490.0, "y1": 0, "y2": 1, "length": 249.0}, {"type": "intron", "altname": "intron", "x1": 6491, "x2": 6986.0, "y1": 0, "y2": 1, "length": 495.0}, {"type": "exon", "altname": "exon", "x1": 6987, "x2": 7324.0, "y1": 0, "y2": 1, "length": 337.0}, {"type": "noncoding", "altname": "noncoding", "x1": 7325, "x2": 10052.0, "y1": 0, "y2": 1, "length": 2727.0}, {"type": "exon", "altname": "exon", "x1": 10053, "x2": 10361.0, "y1": 0, "y2": 1, "length": 308.0}, {"type": "intron", "altname": "intron", "x1": 10362, "x2": 10815.0, "y1": 0, "y2": 1, "length": 453.0}, {"type": "exon", "altname": "exon", "x1": 10816, "x2": 10949.0, "y1": 0, "y2": 1, "length": 133.0}, {"type": "intron", "altname": "intron", "x1": 10950, "x2": 11521.0, "y1": 0, "y2": 1, "length": 571.0}, {"type": "exon", "altname": "exon", "x1": 11522, "x2": 11851.0, "y1": 0, "y2": 1, "length": 329.0}, {"type": "intron", "altname": "intron", "x1": 11852, "x2": 12160.0, "y1": 0, "y2": 1, "length": 308.0}, {"type": "exon", "altname": "exon", "x1": 12161, "x2": 12 ...

# %% [markdown]
# ## Random Chromosome with Custom Mutation Types & Genomic Element Types

# %%
from shadie import ElementList
from shadie import ElementType
from shadie import MutationType
from shadie import MutationList

#create your custom mutation types and save to a MutationList
mut1 = MutationType(0.5, "f", 0)
mut2 = MutationType(0.5, "e", 0.4)
mut3 = MutationType(0.5, "n", 0.4, .1)
mut4 = MutationType(0.5, "w", 0.3, 0.2)
mut5 = MutationType(0.5, "g", -0.4, .1)

mutlist = MutationList(mut1, mut2, mut3, mut4, mut5)

#create your custom genomic element types and save to an ElementList
noncod = ElementType(mut1, 1, altname = "nc")
exon1 = ElementType([mut2, mut5], [1, 1], altname = "ex1")
exon2 = ElementType([mut2, mut3, mut4], [9, 1, .02], altname = "ex2")
intron1 = ElementType([mut2, mut5], [1, 1], altname = "int1")
intron2 = ElementType([mut2, mut5], [1, 1], altname = "int2")

mycustomlist = ElementList(mutlist, noncod, exon1, exon2, intron1, intron2)
# Out:
# 01:50 | WARNING | __init__        | 'g', 'n', and 'w' distributions take 2 params
# 01:50 | WARNING | __init__        | 'g', 'n', and 'w' distributions take 2 params
# 01:50 | WARNING | __init__        | 'e' and 'f' distributions take 1 param
# 01:50 | WARNING | __init__        | 'e' and 'f' distributions take 1 param
# 01:50 | WARNING | __init__        | 'e' and 'f' distributions take 1 param

# %%
from shadie import Build

#initialize the Build class object
custom_build = Build(
    exons = [exon1, exon2], 
    introns = [intron1, intron2], 
    noncoding = [noncod], 
    elementlist = mycustomlist)

# %%
#run the same random function
custom_build.random()
# Out:
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Chromosome complete!

# %%
from shadie import Chromosome

customized_chrom = Chromosome(genome = custom_build)

# %%
customized_chrom.review("elements")
# Out:
# Genomic Elements:
#          name    start   finish eltype  \
# 0          nc        0     3847     g5
# 3848      ex1     3848     4063     g6
# 4064     int1     4064     4639     g8
# 4640      ex2     4640     4900     g7
# 4901       nc     4901     5780     g5
# ...       ...      ...      ...    ...
# 999020   int2   999020   999305     g9
# 999306    ex1   999306   999556     g6
# 999557   int1   999557  1000162     g8
# 1000163   ex1  1000163  1000346     g6
# 1000347    nc  1000347   999999     g5
#
#                                                     script       type
# 0                 'g5', c(m5),c(1), mmJukesCantor(1e-06/3)  noncoding
# 3848       'g6', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)       exon
# 4064       'g8', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)     intron
# 4640     'g7', c(m6, m7, m8),c(9, 1, 0.02), mmJukesCant...       exon
# 4901              'g5', c(m5),c(1), mmJukesCantor(1e-06/3)  noncoding
# ...                                                    ...        ...
# 999020     'g9', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)     intron
# 999306     'g6', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)       exon
# 999557     'g8', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)     intron
# 1000163    'g6', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)       exon
# 1000347           'g5', c(m5),c(1), mmJukesCantor(1e-06/3)  noncoding
#
# [1705 rows x 6 columns]

# %%
import pandas as pd
final_chromosome.genome["name"]

for index, row in final_chromosome.genome.iterrows():
    if pd.isna(row['name']):
        print(row['type'])
    else: 
        print(row['name'])
# Out:
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding

# %%
customized_chrom.review("chromosome")
# Out:
# Chromosome Summary
# # of Genes: 220
# Average # exons per gene: 3.8727272727272726
# Average exon length: 259.46596244131456 nt
# Average # introns per gene: 2.8727272727272726
# Average introns length: 452.40822784810126 nt
#
# Static Chromosome Plot:
# <div class="toyplot" id="tb40ff5d29ae14e22aea8aa46f81b8bf4" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="3000.0px" height="200.0px" viewBox="0 0 3000.0 200.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t41e8998361944cd188a69d0495f63082"><g class="toyplot-coordinates-Cartesian" id="tda58501b7e4940a18e6ff8f94acf6d22"><clipPath id="t43ecd3b3d9ca476fb883d90e733fab62"><rect x="40.0" y="40.0" width="2920.0" height="120.0"></rect></clipPath><g clip-path="url(#t43ecd3b3d9ca476fb883d90e733fab62)"><g class="toyplot-mark-Range" style="stroke:none" id="ta0dcfc221af148eb8e58334d2f1d2956"><g class="toyplot-Series"><rect class="toyplot-Datum" x="50.0" y="50.0" width="11.15243010675296" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t74a2d2af60294ae7b2f8f6e919985e23"><g class="toyplot-Series"><rect class="toyplot-Datum" x="61.15532910080202" y="50.0" width="0.6232837205489687" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t5cf36de5d91146ba8c038f0f57d4742e"><g class="toyplot-Series"><rect class="toyplot-Datum" x="61.78151181540006" y="50.0" width="1.666921578212353" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t88340ff0fbbc4c8cae485af06ef6a6c2"><g class="toyplot-Series"><rect class="toyplot-Datum" x="63.45133238766148" y="50.0" width="0.7537384527568918" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t18b64431de7b40bc87f8b721b56e3924"><g class="toyplot-Series"><rect class="toyplot-Datum" x="64.20796983446743" y="50.0" width="2.54821576912812" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t0dfee1fdb7104631883ff6d64284ebf1"><g class="toyplot-Series"><rect class="toyplot-Datum" x="66.75908459764462" y="50.0" width="1.316143298275506" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t5459ea3dde054985864b48ce6491c544"><g class="toyplot-Series"><rect class="toyplot-Datum" x="68.07812688996918" y="50.0" width="4.606501543964242" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t892f7d81d9ce488c879ed96412b17b9d"><g class="toyplot-Series"><rect class="toyplot-Datum" x="72.68752742798249" y="50.0" width="1.3045473220792445" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t621ce3aa92e8407f955c8bdfb325be46"><g class="toyplot-Series"><rect class="toyplot-Datum" x="73.9949737441108" y="50.0" width="1.142203655331599" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t589368b362c44d6b851255f085ef9c33"><g class="toyplot-Series"><rect class="toyplot-Datum" x="75.14007639349146" y="50.0" width="0.6464756729414916" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="tbc1565eac38344 ...

# %%
customized_chrom.review("interactive")
# Out:
# Interactive altair chromosome map:
# <div id="altair-viz-66b5e872d5574a3aaf7b7f1087efb7ff"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-66b5e872d5574a3aaf7b7f1087efb7ff") {
#       outputDiv = document.getElementById("altair-viz-66b5e872d5574a3aaf7b7f1087efb7ff");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "vconcat": [{"mark": "rect", "encoding": {"color": {"type": "nominal", "field": "altname", "scale": {"domain": ["ex1", "ex2", "int1", "int2", "nc"], "range": ["mediumvioletred", "lightcoral", "lightgoldenrodyellow", "gold", "cornflowerblue"]}}, "tooltip": [{"type": "nominal", "field": "type", "title": "Element Type"}, {"type": "nominal", "field": "altname", "title": "Name"}, {"type": "quantitative", "field": "length", "title": "Length"}, {"type": "quantitative", "field": "x1", "title": "Start"}, {"type": "quantitative", "field": "x2", "title": "Stop"}], "x": {"type": "quantitative", "field": "x1", "scale": {"domain": {"selection": "selector002"}}, "title": null}, "x2": {"field": "x2"}, "y": {"type": "quantitative", "axis": null, "field": "y1"}, "y2": {"field": "y2"}}, "height": 80, "selection": {"selector002": {"type": "interval", "encodings": ["x"], "mark": {"fill": "red", "fillOpacity": 0.7}}}, "width": 850}, {"mark": "rect", "encoding": {"color": {"type": "nominal", "field": "altname", "scale": {"domain": ["ex1", "ex2", "int1", "int2", "nc"], "range": ["mediumvioletred", "lightcoral", "lightgoldenrodyellow", "gold", "cornflowerblue"]}}, "tooltip": [{"type": "nominal", "field": "type", "title": "Element Type"}, {"type": "nominal", "field": "altname", "title": "Name"}, {"type": "quantitative", "field": "length", "title": "Length"}, {"type": "quantitative", "field": "x1", "title": "Start"}, {"type": "quantitative", "field": "x2", "title": "Stop"}], "x": {"type": "quantitative", "axis": {"title": "Base Pairs"}, "field": "x1"}, "x2": {"field": "x2"}, "y": {"type": "quantitative", "axis": null, "field": "y1"}, "y2": {"field": "y2"}}, "height": 40, "selection": {"selector002": {"type": "interval", "encodings": ["x"], "mark": {"fill": "red", "fillOpacity": 0.7}}}, "width": 850}], "data": {"name": "data-2d22ffd5ccd88531e548fe92d354df43"}, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-2d22ffd5ccd88531e548fe92d354df43": [{"type": "noncoding", "altname": "nc", "x1": 0, "x2": 3847.0, "y1": 0, "y2": 1, "length": 3847.0}, {"type": "exon", "altname": "ex1", "x1": 3848, "x2": 4063.0, "y1": 0, "y2": 1, "length": 215.0}, {"type": "intron", "altname": "int1", "x1": 4064, "x2": 4639.0, "y1": 0, "y2": 1, "length": 575.0}, {"type": "exon", "altname": "ex2", "x1": 4640, "x2": 4900.0, "y1": 0, "y2": 1, "length": 260.0}, {"type": "noncoding", "altname": "nc", "x1": 4901, "x2": 5780.0, "y1": 0, "y2": 1, "length": 879.0}, {"type": "exon", "altname": "ex2", "x1": 5781, "x2": 6235.0, "y1": 0, "y2": 1, "length": 454.0}, {"type": "noncoding", "altname": "nc", "x1": 6236, "x2": 7825.0, "y1": 0, "y2": 1, "length": 1589.0}, {"type": "exon", "altname": "ex2", "x1": 7826, "x2": 8276.0, "y1": 0, "y2": 1, "length": 450.0}, {"type": "intron", "altname": "int1", "x1": 8277, "x2": 8671.0, "y1": 0, "y2": 1, "length": 394.0}, {"type": "exon", "altname": "ex1", "x1": 8672, "x2": 8895.0, "y1": 0, "y2": 1, "length": 223.0}, {"type": "intron", "altname": "int1", "x1": 8896, "x2": 9321.0, "y1": 0, "y2": 1, "length": 425.0}, {"type": "exon", "altname": "ex2", "x1": 9322, "x2": 9630.0, "y1": 0, "y2": 1, "length": 308.0}, {"type": "intron", "altname": "int1", "x1": 9631, "x2": 10137.0, "y1": 0, "y2": 1, "length": 506.0}, {"type": "exon", "altname": "ex1", "x1": 10138, "x2": 10437.0, "y1": 0, "y2": 1, "length": 299.0}, {"type": "noncoding", "altname": "nc", "x1": 10438, "x2": 10812.0, "y1": 0, "y2": 1, "length": 374.0}, {"type": "exon", "altname": "ex2", "x1": 10813, "x2": 10978.0, "y1": 0, "y2": 1, "length": 165.0}, {"type": "noncoding", "altname": "nc", "x1": 10979, "x2": 12614.0, "y1": 0, "y2": 1, "length": 1635.0}, {"type": "exon", "altname": "ex1", "x1": 12615, "x2": 12927.0, "y1": 0, "y2": 1, "length": 312.0}, {"type": "noncoding", "altname": "nc", "x1": 12928, "x2": 13763.0, "y1": 0, "y2": 1, "length": 835.0}, {"type": "exon", "altname": "ex1", "x1": 1376 ...

# %% [markdown]
# ## Custom Chromosome
# Finally, you can define your own chromosome by providing a pandas dataframe that contains, at minimum, the `name` of the genomic element (as defined by you *or* using `shadie` defaults), the `start base` and the `end base`. Alternatively, you can provide the internal `idx` of the genomic element (in place of the `name`). You must provide a GenomeList class object and your genomic elements must be defined in the list.
