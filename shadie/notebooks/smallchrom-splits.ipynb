# %% [markdown]
# # Split Demography with Small Chromosome - Standard Params

# %%
import shadie

# %%
neut_chrom_small = shadie.chromosome.explicit({
    (0, 900_000): shadie.NONCDS,})

chrom_small = shadie.chromosome.explicit({
    (0, 100_000): shadie.NONCDS,
    (100_001, 120_000): shadie.EXON,
    (120_001, 130_000): shadie.INTRON,
    (130_001, 150_000): shadie.EXON,
    (150_001, 750_000): shadie.NONCDS,
    (750_001, 770_000): shadie.EXON,
    (770_001, 780_000): shadie.INTRON,
    (780_001, 800_000): shadie.EXON,
    (800_001, 900_000): shadie.NONCDS,
})
chrom_small.draw();
# Out:
# <div class="toyplot" id="t826074ccfd534d10916148c7e3384980" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="700.0px" height="150.0px" viewBox="0 0 700.0 150.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t2b4efc154fa14399831aab10d53df549"><g class="toyplot-coordinates-Cartesian" id="tdad38863df9b4e4ba921666ece993e17"><clipPath id="t2a01ab87e56c476c895527da8219049b"><rect x="40.0" y="40.0" width="620.0" height="70.0"></rect></clipPath><g clip-path="url(#t2a01ab87e56c476c895527da8219049b)"><g class="toyplot-mark-FillBoundaries" style="stroke:rgb(0%,0%,0%);stroke-opacity:1.0" id="t75e9f913cccb4d9f9c31
# ...

# %%
#sim params
GENS = 1_000
SPO_POPSIZE = 1_000
GAM_POPSIZE = 2_000
MUT= 1e-7
RECOMB= 1e-8
CHROMOSOME = chrom_small

# %%
#check that all the trees are equivalent
merged_bryomono.tree_sequence.max_root_time, merged_bryodio.tree_sequence.max_root_time, merged_pterhomo.tree_sequence.max_root_time, merged_pterhetero.tree_sequence.max_root_time
# Out:
# (5000.0, 5000.0, 5000.0, 5000.0)

# %% [markdown]
# ## Stats

# %%
merged_bryomono.stats()
# Out:
#              mean     CI_5%    CI_95%
# theta_0  0.000083  0.000071  0.000095
# theta_1  0.000040  0.000038  0.000043
# Fst_01   0.414242  0.391344  0.437141
# Dist_01  0.000148  0.000141  0.000155
# D_Taj_0 -0.542691 -0.902952 -0.182430
# D_Taj_1 -1.459607 -1.691502 -1.227712

# %%
merged_bryomono.stats(sample=100)
# Out:
#              mean     CI_5%    CI_95%
# theta_0  0.000084  0.000081  0.000086
# theta_1  0.000041  0.000041  0.000042
# Fst_01   0.406633  0.402534  0.410732
# Dist_01  0.000148  0.000146  0.000150
# D_Taj_0 -1.061018 -1.167694 -0.954342
# D_Taj_1 -2.079442 -2.121954 -2.036930

# %%
merged_bryodio.stats(sample=100)
# Out:
#              mean     CI_5%    CI_95%
# theta_0  0.000038  0.000034  0.000043
# theta_1  0.000130  0.000127  0.000133
# Fst_01   0.411804  0.401320  0.422288
# Dist_01  0.000202  0.000200  0.000203
# D_Taj_0 -1.997693 -2.173641 -1.821745
# D_Taj_1 -0.350934 -0.502322 -0.199545

# %%
merged_pterhomo.stats()
# Out:
#              mean     CI_5%    CI_95%
# theta_0  0.000012  0.000011  0.000014
# theta_1  0.000055  0.000044  0.000066
# Fst_01   0.633762  0.585109  0.682414
# Dist_01  0.000149  0.000148  0.000150
# D_Taj_0 -1.578945 -1.810212 -1.347677
# D_Taj_1 -1.172549 -1.383478 -0.961619

# %%
merged_pterhetero.stats()
# Out:
#              mean     CI_5%    CI_95%
# theta_0  0.000087  0.000080  0.000093
# theta_1  0.000041  0.000038  0.000043
# Fst_01   0.403905  0.375463  0.432348
# Dist_01  0.000150  0.000142  0.000158
# D_Taj_0  0.247181 -0.038907  0.533270
# D_Taj_1 -0.415585 -0.677085 -0.154086

# %%
#why is bryodio Fst so low??
for i in merged_bryodio.tree_sequence.mutations():
    print(merged_bryodio.tree_sequence.mutation(i.id).metadata['mutation_list'][0])
# Out:
# {'mutation_type': 1, 'selection_coeff': 0.0, 'subpopulation': 0, 'slim_time': 5001, 'nucleotide': -1}
# {'mutation_type': 1, 'selection_coeff': 0.0, 'subpopulation': 0, 'slim_time': 5001, 'nucleotide': -1}
# {'mutation_type': 1, 'selection_coeff': 0.0, 'subpopulation': 0, 'slim_time': 4001, 'nucleotide': -1}
# {'mutation_type': 1, 'selection_coeff': 0.0, 'subpopulation': 0, 'slim_time': 4001, 'nucleotide': -1}
# {'mutation_type': 1, 'selection_coeff': 0.0, 'subpopulation': 0, 'slim_time': 4757, 'nucleotide': -1}
# {'mutation_type': 1, 'selection_coeff': 0.0, 'subpopulation': 0, 'slim_time': 4757, 'nucleotide': -1}
# {'mutation_type': 1, 'selection_coeff': 0.0, 'subpopulation': 0, 'slim_time': 4001, 'nucleotide': -1}
# {'mutation_type': 1, 'selection_coeff': 0.0, 'subpopulation': 0, 'slim_time': 4001, 'nucleotide': -1}
# {'mutation_type': 1, 'selection_coeff': 0.0, 'subpopulation': 0, 'slim_time': 4001, 'nucleotide': -1}
# ...

# %%
merged_bryodio.tree_sequence.mutation(1)
# Out:
# Mutation(id=1, site=0, node=295549, derived_state='174391647', parent=-1, metadata={'mutation_list': [{'mutation_type': 1, 'selection_coeff': 0.0, 'subpopulation': 0, 'slim_time': 5001, 'nucleotide': -1}]}, time=0.0)

# %% [markdown]
# ### Compare maternal effects to no maternal effects

# %%
merged_pterhetero_mateffect.stats(sample=100)
# Out:
#              mean     CI_5%    CI_95%
# theta_0  0.000039  0.000037  0.000041
# theta_1  0.000090  0.000089  0.000091
# Fst_01   0.387550  0.380105  0.394995
# Dist_01  0.000146  0.000145  0.000148
# D_Taj_0 -1.593223 -1.691585 -1.494861
# D_Taj_1 -0.527234 -0.609657 -0.444811

# %%
merged_pterhetero.stats(sample=50)
# Out:
#              mean     CI_5%    CI_95%
# theta_0  0.000086  0.000084  0.000087
# theta_1  0.000039  0.000038  0.000040
# Fst_01   0.424157  0.416382  0.431932
# Dist_01  0.000154  0.000152  0.000157
# D_Taj_0  0.338607  0.257700  0.419514
# D_Taj_1 -0.842923 -0.955043 -0.730804

# %% [markdown]
# ### Compare across 4 runs

# %%
merged_pterhetero2.stats(sample=50)
# Out:
#              mean     CI_5%    CI_95%
# theta_0  0.000063  0.000061  0.000065
# theta_1  0.000039  0.000039  0.000040
# Fst_01   0.455377  0.446125  0.464629
# Dist_01  0.000137  0.000135  0.000138
# D_Taj_0  0.226428  0.091897  0.360960
# D_Taj_1 -0.986797 -1.036070 -0.937523

# %%
merged_pterhetero3.stats(sample=50)
# Out:
#              mean     CI_5%    CI_95%
# theta_0  0.000110  0.000104  0.000115
# theta_1  0.000062  0.000059  0.000065
# Fst_01   0.309314  0.296626  0.322003
# Dist_01  0.000163  0.000161  0.000164
# D_Taj_0  0.890172  0.669249  1.111095
# D_Taj_1  0.389227  0.185543  0.592912

# %%
merged_pterhetero4.stats(sample=50)
# Out:
#              mean     CI_5%    CI_95%
# theta_0  0.000112  0.000106  0.000117
# theta_1  0.000086  0.000085  0.000087
# Fst_01   0.266184  0.251292  0.281075
# Dist_01  0.000171  0.000168  0.000173
# D_Taj_0  0.997552  0.711842  1.283263
# D_Taj_1  0.425316  0.321585  0.529046

# %%
merged_pterhetero5.stats(sample=50)
# Out:
#              mean     CI_5%    CI_95%
# theta_0  0.000064  0.000060  0.000069
# theta_1  0.000087  0.000085  0.000089
# Fst_01   0.223214  0.217511  0.228917
# Dist_01  0.000119  0.000117  0.000121
# D_Taj_0  0.489208  0.265350  0.713066
# D_Taj_1  0.332700  0.238483  0.426918

# %%
merged_pterhetero5.draw_stats()
# Out:
# (<toyplot.canvas.Canvas at 0x7f23f090d190>,
# ...
#  <toyplot.mark.FillBoundaries at 0x7f23f09193a0>)
# ...

# %%
merged_pterhetero2.draw_stats()
# Out:
# (<toyplot.canvas.Canvas at 0x7f23f4379d00>,
# ...
#  <toyplot.mark.FillBoundaries at 0x7f23f0901f10>)
# ...

# %%
merged_pterhetero6.stats(sample=50)

# %%
# Out:
#              mean     CI_5%    CI_95%
# theta_0  0.000111  0.000104  0.000118
# theta_1  0.000040  0.000039  0.000041
# Fst_01   0.382019  0.358225  0.405814
# Dist_01  0.000168  0.000165  0.000172
# D_Taj_0  0.898809  0.675880  1.121737
# D_Taj_1 -0.811690 -0.900708 -0.722672

# %%
pter_hetero_fsts = []

# %% [markdown]
# ### Compare small chromosome and medium chromosome

# %%
merged_pterhetero_medchrom = shadie.postsim.PureSlim_TwoPops(["../pter_hetero_run1_medchrom_1000spo.trees",
                                          "../pter_hetero_run2_medchrom_1000spo.trees"],
                                         generations = GENS,
                                         popsize = SPO_POPSIZE,
                                         recomb = RECOMB,
                                         mut = MUT,
                                         chromosome = CHROMOSOME,
                                         )
# Out:
# 11:45 | INFO    | _report_ninds   | inds alive at time=0; simpop0=93554, simpop1=139199

# %%
merged_pterhetero.stats(sample=50)
# Out:
#              mean     CI_5%    CI_95%
# theta_0  0.000086  0.000085  0.000088
# theta_1  0.000040  0.000039  0.000041
# Fst_01   0.414920  0.405291  0.424548
# Dist_01  0.000153  0.000151  0.000155
# D_Taj_0  0.377435  0.288426  0.466445
# D_Taj_1 -0.842289 -0.942161 -0.742416

# %%
merged_pterhetero.draw_stats()
# Out:
# (<toyplot.canvas.Canvas at 0x7f23f08ec340>,
# ...
#  <toyplot.mark.FillBoundaries at 0x7f23f09082b0>)
# ...

# %%
merged_pterhetero_medchrom.stats(sample=50)
# Out:
#              mean     CI_5%    CI_95%
# theta_0  0.000020  0.000019  0.000021
# theta_1  0.000015  0.000014  0.000017
# Fst_01   0.810907  0.801303  0.820512
# Dist_01  0.000170  0.000169  0.000170
# D_Taj_0 -1.278121 -1.406345 -1.149898
# D_Taj_1 -1.840033 -2.053123 -1.626943

# %%
merged_pterhetero_medchrom.draw_stats(window_size=100_000)
# Out:
# (<toyplot.canvas.Canvas at 0x7f23f08e14c0>,
# ...
#  <toyplot.mark.FillBoundaries at 0x7f23f433ba30>)
# ...

# %% [markdown]
# ## Read in the merged files

# %%
merged_bryomono = shadie.postsim.PureSlim_TwoPops(["bryo_mono_run1_from_smallchrom_2000spo.trees",
                                          "bryo_mono_run2_smallchrom_2000spo.trees"],
                                         generations = GENS,
                                         popsize = SPO_POPSIZE,
                                         recomb = RECOMB,
                                         mut = MUT,
                                         chromosome = CHROMOSOME,
                                         )
# Out:
# 08:40 | INFO    | _report_ninds   | inds alive at time=0; simpop0=45640, simpop1=60363

# %%
merged_bryodio = shadie.postsim.PureSlim_TwoPops(["bryo_dio_run2_from_smallchrom_2000spo.trees",
                                          "bryo_dio_run3_from_smallchrom_2000spo.trees"],
                                         generations = GENS,
                                         popsize = SPO_POPSIZE,
                                         recomb = RECOMB,
                                         mut = MUT,
                                         chromosome = CHROMOSOME,
                                         )
# Out:
# 10:46 | INFO    | _report_ninds   | inds alive at time=0; simpop0=58658, simpop1=53000

# %%
merged_pterhomo = shadie.postsim.PureSlim_TwoPops(["pter_homospore_run1_from_smallchrom_2000spo.trees",
                                          "pter_homospore_run2_from_smallchrom_2000spo.trees"],
                                         generations = GENS,
                                         popsize = SPO_POPSIZE,
                                         recomb = RECOMB,
                                         mut = MUT,
                                         chromosome = CHROMOSOME,
                                         )
# Out:
# 08:41 | INFO    | _report_ninds   | inds alive at time=0; simpop0=105338, simpop1=78932

# %%
merged_pterhetero = shadie.postsim.PureSlim_TwoPops(["pter_hetero_run1.trees",
                                          "pter_hetero_run2.trees"],
                                         generations = GENS,
                                         popsize = SPO_POPSIZE,
                                         recomb = RECOMB,
                                         mut = MUT,
                                         chromosome = CHROMOSOME,
                                         )
# Out:
# 08:41 | INFO    | _report_ninds   | inds alive at time=0; simpop0=144860, simpop1=188355

# %%
merged_pterhetero2 = shadie.postsim.PureSlim_TwoPops(["pter_hetero_run1.trees",
                                          "pter_hetero_run3.trees"],
                                         generations = GENS,
                                         popsize = SPO_POPSIZE,
                                         recomb = RECOMB,
                                         mut = MUT,
                                         chromosome = CHROMOSOME,
                                         )
# Out:
# 10:53 | INFO    | _report_ninds   | inds alive at time=0; simpop0=150267, simpop1=188355

# %%
merged_pterhetero3 = shadie.postsim.PureSlim_TwoPops(["pter_hetero_run3.trees",
                                          "pter_hetero_run4.trees"],
                                         generations = GENS,
                                         popsize = SPO_POPSIZE,
                                         recomb = RECOMB,
                                         mut = MUT,
                                         chromosome = CHROMOSOME,
                                         )
# Out:
# 10:54 | INFO    | _report_ninds   | inds alive at time=0; simpop0=145945, simpop1=150267

# %%
merged_pterhetero4 = shadie.postsim.PureSlim_TwoPops(["pter_hetero_run2.trees",
                                          "pter_hetero_run4.trees"],
                                         generations = GENS,
                                         popsize = SPO_POPSIZE,
                                         recomb = RECOMB,
                                         mut = MUT,
                                         chromosome = CHROMOSOME,
                                         )
# Out:
# 10:54 | INFO    | _report_ninds   | inds alive at time=0; simpop0=145945, simpop1=144860

# %%
merged_pterhetero5 = shadie.postsim.PureSlim_TwoPops(["pter_hetero_run2.trees",
                                          "pter_hetero_run3.trees"],
                                         generations = GENS,
                                         popsize = SPO_POPSIZE,
                                         recomb = RECOMB,
                                         mut = MUT,
                                         chromosome = CHROMOSOME,
                                         )
# Out:
# 10:55 | INFO    | _report_ninds   | inds alive at time=0; simpop0=150267, simpop1=144860

# %%
merged_pterhetero6 = shadie.postsim.PureSlim_TwoPops(["pter_hetero_run1.trees",
                                          "pter_hetero_run4.trees"],
                                         generations = GENS,
                                         popsize = SPO_POPSIZE,
                                         recomb = RECOMB,
                                         mut = MUT,
                                         chromosome = CHROMOSOME,
                                         )
# Out:
# 10:57 | INFO    | _report_ninds   | inds alive at time=0; simpop0=145945, simpop1=188355

# %%
merged_pterhetero_mateffect = shadie.postsim.PureSlim_TwoPops(["pter_hetero_run1_mateffect.trees",
                                          "pter_hetero_run2_mateffect.trees"],
                                         generations = GENS,
                                         popsize = SPO_POPSIZE,
                                         recomb = RECOMB,
                                         mut = MUT,
                                         chromosome = CHROMOSOME,
                                         )

# %%
merged_angiomono = shadie.postsim.PureSlim_TwoPops(["an",
                                          "angio_mono_run2_from_smallchrom_2000spo.trees"],
                                         generations = GENS,
                                         popsize = SPO_POPSIZE,
                                         recomb = RECOMB,
                                         mut = MUT,
                                         chromosome = CHROMOSOME,
                                         )

# %%
merged_angiodio = shadie.postsim.PureSlim_TwoPops(["",
                                          "angio_mono_run2_from_smallchrom_2000spo.trees"],
                                         generations = GENS,
                                         popsize = SPO_POPSIZE,
                                         recomb = RECOMB,
                                         mut = MUT,
                                         chromosome = CHROMOSOME,
                                         )
