# %% [markdown]
# # Building a Chromosome for `shadie`
#
# The simplest way to prepare a SLiM simulation using `shadie` is to let the `Chromosome` class automatically generate a single gene. The gene will consist of a single exon by default, although the user can also specify number of exons. The user can also supply a length (in base pairs) for the `genome_size` argument.

# %%
import shadie

# %%
shadie.

# %%
shadie.chrom.random()
shadie.chrom.explicit()
shadie.chrom.standard()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-be9841a232fb> in <module>
# ----> 1 shadie.chrom.random()
#       2 shadie.chrom.explicit()
#       3 shadie.chrom.standard()
#
# AttributeError: module 'shadie' has no attribute 'chrom'

# %%
shadie.build.random()

# %%
shadie.build.ChromosomeRandoma
# Out:
# shadie.build.ChromosomeBase

# %%
c = shadie..standard()
c.data
c.inspect()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-d705e7ad5dce> in <module>
# ----> 1 c = shadie.chromosome.standard()
#       2 c.data
#       3 c.inspect()
#
# AttributeError: module 'shadie.chromosome' has no attribute 'standard'

# %%
from shadie.build import *

# %%
ChromosomeStandard().data.head()
# Out:
#         name start    end eltype  \
# 0     noncds     0   2000     g3
# 2000    exon  2000   4000     g1
# 4000  intron  4000   6000     g2
# 6000    exon  6000   8000     g1
# 8000  noncds  8000  10000     g3
#
#                                                  script
# 0     <ElementType: noncds, g3, ['m1'], [1], mmJukes...
# 2000  <ElementType: exon, g1, ['m3', 'm4'], (8, 0.1)...
# 4000  <ElementType: intron, g2, ['m3'], [1], mmJukes...
# 6000  <ElementType: exon, g1, ['m3', 'm4'], (8, 0.1)...
# 8000  <ElementType: noncds, g3, ['m1'], [1], mmJukes...

# %%
ChromosomeExplicit({50: INTRON, 100: EXON, 150: INTRON}).data
# Out:
#        name start  end eltype  \
# 0    intron     0   50     g2
# 50     exon    50  150     g1
# 150  intron   150  300     g2
#
#                                                 script
# 0    <ElementType: intron, g2, ['m3'], [1], mmJukes...
# 50   <ElementType: exon, g1, ['m3', 'm4'], (8, 0.1)...
# 150  <ElementType: intron, g2, ['m3'], [1], mmJukes...

# %%
class ChromosomeBase:
    def __init__(self, genome_size):
        self.genome_size = genome_size
        self.data = pd.DataFrame(
            columns=['type', 'name', 'start', 'finish', 'eltype', 'script'],
            data=None,
        )       


class Random(ChromosomeBase):
    def __init__(self, genome_size=20000, seed=None):
        super().__init__(genome_size)
        self.rng = np.random.default_rng(seed)
        # self.intron = INTRON
        # self.exon = EXON
        # self.noncds = NONCDS


    def get_noncds_span(self, scale=5000):
        """
        Draws the number of bases until the next element from an 
        exponential distribution. The scale is the average waiting
        time in number of bp.
        """
        return int(self.rng.exponential(scale=scale))


    def get_cds_spans(self, length_scale=1000, intron_scale=1000):
        """
        Draws the number of exons in a fixed length space from a 
        Poisson distribution. The lam parameter is the average number
        of events per sampled region. A value of 0.005 means one intron
        per 200bp.
        """
        cds_span = int(self.rng.exponential(scale=length_scale))
        n_introns = int(self.rng.poisson(cds_span / intron_scale))
        if n_introns:
            splits = self.rng.dirichlet(np.ones(n_introns * 2 - 1))
            splits = (splits * cds_span).astype(int)
            splits[-1] = cds_span - sum(splits[:-1])
        else:
            splits = np.array([cds_span])
        return splits

    def run(self):
        """
        ...
        """
        idx = 0
        
        while 1:
            # get non-cds span
            pos = self.get_noncds_span()
            self.data.loc[idx] = (
                "noncoding", 
                None, 
                idx, 
                min(idx + pos, self.genome_size), 
                self.noncds.name, 
                self.noncds,
            )
            idx += pos
            
            # get cds span
            posses = self.get_cds_spans()

            # break if cds goes beyond the end of the genome.
            if idx + posses.sum() > self.genome_size:
                break

            # enter the cds into data
            for enum, pos in enumerate(posses):
                if not enum % 2:
                    self.data.loc[idx] = (
                        "exon", 
                        None, 
                        idx, 
                        idx + pos, 
                        self.exon.name, 
                        self.exon,
                    )
                else:
                    self.data.loc[idx] = (
                        "intron", 
                        None, 
                        idx, 
                        idx + pos, 
                        self.intron.name, 
                        self.intron,
                    )
                idx += pos

# %%
m0 = shadie.mtype(0.5, 'n', 1.0, 0.5)
m1 = shadie.mtype(0.5, 'n', 2.0, 1.0)
m2 = shadie.mtype(0.5, 'f', 0.0)
e0 = shadie.etype([m0, m1], [0.5, 1.0])
e1 = shadie.etype([m2], [1.0])
l0 = shadie.elist(e0, e1)

# %%
c = Random(100000)

# %%
c.intron = e1
c.exon = e0
c.noncds = e1

# %%
c.run()

# %%
c.data.script[0]
# Out:
# <ElementType: None, g48, ['m72'], [1.0], mmJukesCantor(1e-09/3)>

# %%
c.get_cds_spans().sum()
# Out:
# 90

# %%
idx = 0
while 1:
    
    # get noncds span
    pos = c.get_span(5000)
    
    # enter noncds span
    c.data.loc[idx] = "noncoding", None, idx, pos, c.noncds.name, c.noncds

    # get cds span
    pos = c.get_span(1000)

    # split cds into introns
    nintrons = c.get_n_introns_in_cds(1 / 300.)
    splits = c.get_cds_spans(pos, nintrons)

# %%
np.random.exponential(1000)
# Out:
# 402.60767324553086

# %%
np.random.poisson(1000 * 1/1000)
# Out:
# 1

# %%
xs = np.random.dirichlet(np.ones(3))

# %%
(xs * 1000).astype(int)
# Out:
# array([ 80, 428, 491])

# %%
80 + 428 + 491
# Out:
# 999

# %%
idx = 0
while 1:
    
pos = 500
c.data.loc[0] = "noncoding", None, idx, pos, c.noncds.name, c.noncds
idx = 500
pos = 800
c.data.loc[500] = "exon", None, idx, pos, c.exon.name, c.exon
c.data
# Out:
#           type  name start finish eltype  \
# 0    noncoding  None     0    500     g4
# 500       exon  None   500    800     g3
#
#                                                 script
# 0    <ElementType: None, g4, ['m6'], [1.0], mmJukes...
# 500  <ElementType: None, g3, ['m4', 'm5'], [0.5, 1....

# %% [markdown]
# ### Mutations

# %%
NEUTRAL = shadie.mtype(0.5, 'f', 0.0)
SYNONYMOUS = shadie.mtype(0.5, 'f', 0.00)
DELETERIOUS = shadie.mtype(0.5, 'g', -2.0, 0.05)
BENEFICIAL = shadie.mtype(0.5, 'e', 0.5)

mlist = shadie.mlist(DELETERIOUS, BENEFICIAL).draw(width=400);
# Out:
# <div class="toyplot" id="tb0395ccc9ba14e15a745d362245f66bb" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="225.0px" viewBox="0 0 400.0 225.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t9d4c6f4877e5489088a19ddd0713aa41"><g class="toyplot-coordinates-Cartesian" id="t8f9561a1a9d84294a59132a49b0c8499"><clipPath id="tb26b015e633140b9afa6f6bcae1e16ac"><rect x="40.0" y="40.0" width="320.0" height="145.0"></rect></clipPath><g clip-path="url(#tb26b015e633140b9afa6f6bcae1e16ac)"><g class="toyplot-mark-FillBoundaries" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:0.33;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:1.5" id="t8b31a488c84e4d85ac9482802173d26a"><polygon points="50.0,175.0 50.36750058245772,175.0 50.73500116491546,175.0 51.10250174737318,175.0 51.470002329830905,175.0 51.837502912288635,175.0 52.205003494746364,175.0 52.57250407720409,175.0 52.94000465966181,175.0 53.30750524211955,175.0 53.67500582457727,175.0 54.04250640703499,175.0 54.41000698949272,175.0 54.77750757195045,175.0 55.145008154408174,175.0 55.512508736865904,175.0 55.880009319323634,175.0 56.247509901781356,175.0 56.61501048423908,175.0 56.982511066696816,175.0 57.35001164915454,175.0 57.71751223161227,175.0 58.08501281406999,175.0 58.45251339652772,175.0 58.82001397898544,175.0 59.187514561443166,175.0 59.5550151439009,175.0 59.922515726358625,175.0 60.29001630881635,175.0 60.657516891274085,175.0 61.02501747373181,175.0 61.39251805618953,175.0 61.76001863864726,175.0 62.12751922110499,175.0 62.49501980356272,175.0 62.86252038602044,175.0 63.23002096847817,175.0 63.5975215509359,175.0 63.965022133393624,175.0 64.33252271585135,175.0 64.70002329830908,175.0 65.0675238807668,175.0 65.43502446322452,175.0 65.80252504568226,175.0 66.17002562813998,175.0 66.53752621059772,175.0 66.90502679305544,175.0 67.27252737551316,175.0 67.64002795797089,175.0 68.00752854042862,175.0 68.37502912288635,175.0 68.74252970534407,175.0 69.1100302878018,175.0 69.47753087025953,175.0 69.84503145271725,175.0 70.21253203517497,175.0 70.58003261763271,175.0 70.94753320009045,175.0 71.31503378254816,175.0 71.68253436500588,175.0 72.05003494746362,175.0 72.41753552992134,175.0 72.78503611237906,175.0 73.1525366948368,175.0 73.52003727729453,175.0 73.88753785975226,175.0 74.25503844220998,175.0 74.6225390246677,175.0 74.99003960712544,175.0 75.35754018958316,175.0 75.7250407720409,175.0 76.09254135449862,175.0 76.46004193695634,175.0 76.82754251941407,175.0 77.19504310187179,175.0 77.56254368432951,175.0 77.93004426678723,175.0 78.29754484924499,175.0 78.66504543170271,175.0 79.03254601416043,175.0 79.40004659661815,175.0 79.76754717907588,175.0 80.13504776153361,175.0 80.50254834399134,175.0 80.87004892644907,175.0 81.2375495089068,175.0 81.60505009136452,175.0 81.97255067382224,175.0 82.34005125627996,175.0 82.7075518387377,175.0 83.07505242119544,175.0 83.44255300365316,175.0 83.81005358611088,175.0 84.1775541685686,175.0 84.54505475102633,175.0 84.91255533348405,175.0 85.28005591594177,175.0 85.64755649839952,175.0 86.01505708085725,175.0 86.38255766331497,175.0 86.38255766331497,143.29042914485206 86.01505708085725,124.49515672143893 85.64755649839952,108.54273467784756 85.28005591594177,95.12321893517102 84.91255533348405,83.95641861596195 84.54505475102633,74.78922837318171 84.1775541685686,67.39318991038678 83.81005358611088,61.562263569426534 83.44255300365316,57.11079242402139 83.07505242119544,53.87164275414 82.7075518387377,51.69450609705358 82.34005125627996,50.44434928550015 81.97255067382224,50.0 81.60505009136452,50.25285638881904 81.2375495089068,51.105 ...

# %% [markdown]
# ### Elements

# %%
INTRON = shadie.etype([NEUTRAL], [1])
EXON = shadie.etype([SYNONYMOUS, DELETERIOUS, BENEFICIAL], [33, 66, 1])
NONCDS = shadie.etype([NEUTRAL], [1], mutation_rate=0.0)

# %%
import numpy as np

# %%
rng = np.random.default_rng()

# %%
rng.poisson(lam=1/100)
# Out:
# 0

# %%
rng.exponential(scale=100.0)
# Out:
# 94.49656093528965

# %%
scipy.stats.expon.rvs(loc=0, scale=100, size=10000).mean()
# Out:
# 101.49552365619441

# %%
scipy.stats.poisson.rvs(loc=0, mu=100, size=10000).mean()
# Out:
# 99.9187

# %% [markdown]
# ### Chromosome

# %%
# chromosome.random()
# chromosome.explicit()

# %%
class Build:
    def __init__(self, introns, exons, noncds):
        self.introns = introns
        self.exons = exons
        self.noncds = noncds

# %%
bld = Build(INTRON, EXON, NONCDS)
bld

# %%
Chromosome(100).random()

# %%
import io

# %%
one_gene = Chromosome(2000)

# %%
#create Chromosome object. If no "genome" argument is supplied, the Chromosome class will generate a single gene
one_gene = Chromosome(genome_size = 2000)
# Out:
# 01:06 | INFO    | genes           | Chromosome complete!

# %%
#the Chromosome object can now be inspected using review() function
Chromosome.review(one_gene, item = "mutations")
Chromosome.review(one_gene, item = "eltypes")
Chromosome.review(one_gene, item = "elements")

#simpler syntax
one_gene.review("chromosome")
# Out:
# Mutation Types:
#  <MutationList: ['m1', 'm2', 'm3', 'm4']>
#
# Genomic Element Types:
#  <ElementList: ['g1', 'g3']>
#
# Genomic Elements:
#            type name start finish eltype  \
# 0     noncoding  NaN     0    308     g3
# 309        exon  NaN   309   1409     g1
# 1410  noncoding  NaN  1410   1999     g3
#
#                                                  script
# 0     <ElementType: 'None', g3, ['m1'], [1], mmJukes...
# 309   <ElementType: 'None', g1, ['m3', 'm4'], [8, 0....
# 1410  <ElementType: 'None', g3, ['m1'], [1], mmJukes...
# Chromosome Summary
# # of Genes: 1
# Average # exons per gene: 1.0
# Average exon length: 1101.0 nt
# Average # introns per gene: 0.0
# Average introns length: 0 nt
#
# Static Chromosome Plot:
# <div class="toyplot" id="t4ec3623421624b5d8c9c1ee55396baf9" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="3000.0px" height="200.0px" viewBox="0 0 3000.0 200.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t1ee55de280c54754995649aa3f85da16"><g class="toyplot-coordinates-Cartesian" id="t29d1efbf3524482298831a85c91d1126"><clipPath id="t82fd5bb389aa4922b626f2ef7a88d071"><rect x="40.0" y="40.0" width="2920.0" height="120.0"></rect></clipPath><g clip-path="url(#t82fd5bb389aa4922b626f2ef7a88d071)"><g class="toyplot-mark-Range" style="stroke:none" id="tb6d6722c01204032b11a64ec9b979179"><g class="toyplot-Series"><rect class="toyplot-Datum" x="50.0" y="50.0" width="446.6" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t7c8badcccf3544cb8dd4d5d7188d8999"><g class="toyplot-Series"><rect class="toyplot-Datum" x="498.04999999999995" y="50.0" width="1595.0000000000002" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t2fcd2cd5c8654289bd7da47174536c3d"><g class="toyplot-Series"><rect class="toyplot-Datum" x="2094.5" y="50.0" width="854.0500000000002" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g></g><g class="toyplot-coordinates-Axis" id="t91a8b8ee56f74adba42f096e07dd217c" transform="translate(50.0,150.0)translate(0,10.0)"><line x1="0" y1="0" x2="2898.55" y2="0" style=""></line><g><g transform="translate(0.0,6)"><text x="-2.78" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">0</text></g><g transform="translate(725.0,6)"><text x="-8.34" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">500</text></g><g transform="translate(1450.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">1000</text></g><g transform="translate(2175.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">1500</text></g><g transform="translate(2900.0,6)"><text x="-11.12" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">2000</text></g></g><g class="toyplot-coordinates-Axis-coordinates" style="visibility:hidden" transform=""><line x1="0" x2="0" y1="-3.0" y2="4.5" style="stroke:rgb(43.9%,50.2%,56.5%);stroke-opacity:1.0;stroke-width:1.0"></line><text x="0" y="-6" style="alignment-baseline:alphabetic;fill:rgb(43.9%,50.2%,56.5%);fill-opacity:1.0;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle"></text></g></g><g class="toyplot-coordinates-Axis" id="td767ba412e34456cb6d7f0860e979e36" transform="translate(50.0,150.0)rotate(-90.0)translate(0,-10.0)"><line x1="0" y1="0" x2="100.0" y2="0" style=""></line><g><g transform="translate(0.0,-6)"><text x="-6.95" y="-4.440892098500626e-16" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">0.0</text></g><g  ...
# {
# var modules={};
# modules["toyplot/canvas/id"] = "t1ee55de280c54754995649aa3f85da16";
# modules["toyplot/canvas"] = (function(canvas_id)
#     {
#         return document.querySelector("#" + canvas_id);
#     })(modules["toyplot/canvas/id"]);
# modules["toyplot.coordinates.Axis"] = (
#         function(canvas)
#         {
#             function sign(x)
#             {
#                 return x < 0 ? -1 : x > 0 ? 1 : 0;
#             }
#
#             function mix(a, b, amount)
#             {
#                 return ((1.0 - amount) * a) + (amount * b);
#             }
#
#             function log(x, base)
#             {
#                 return Math.log(Math.abs(x)) / Math.log(base);
#             }
#
#             function in_range(a, x, b)
#             {
#                 var left = Math.min(a, b);
#                 var right = Math.max(a, b);
#                 return left <= x && x <= right;
#             }
#
#             function inside(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.min, range, segment.range.max))
#                         return true;
#                 }
#                 return false;
#             }
#
#             function to_domain(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#                     {
#                         if(segment.scale == "linear")
#                         {
#                             var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#                             return mix(segment.domain.min, segment.domain.max, amount)
#                         }
#                         else if(segment.scale[0] == "log")
#                         {
#                             var amount = (range - segment.range.min) / (segment.range.max - segment.range.min);
#                             var base = segment.scale[1];
#                             return sign(segment.domain.min) * Math.pow(base, mix(log(segment.domain.min, base), log(segment.domain.max, base), amount));
#                         }
#                     }
#                 }
#             }
#
#             var axes = {};
#
#             function display_coordinates(e)
#             {
#                 var current = canvas.createSVGPoint();
#                 current.x = e.clientX;
#                 current.y = e.clientY;
#
#                 for(var axis_id in axes)
#                 {
#                     var axis = document.querySelector("#" + axis_id);
#                     var coordinates = axis.querySelector(".toyplot-coordinates-Axis-coordinates");
#                     if(coordinates)
#                     {
#                         var projection = axes[axis_id];
#                         var local = current.matrixTransform(axis.getScreenCTM().inverse());
#                         if(inside(local.x, projecti

# %% [markdown]
# ## Random Chromosome
# You can also use the `Build` class of `shadie` to generate a random chromosome for you:

# %%
from shadie import Build

# %%
#create a Build class object
random_chromosome = Build()

#run the random() function to generate the chromosome
Build.random(random_chromosome)
# Out:
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Gene added
# 01:07 | INFO    | random          | Chromosome complete!

# %%
print(random_chromosome.mutationlist)
# Out:
# <MutationList: ['m1', 'm2', 'm3', 'm4']>

# %% [markdown]
# ### Pass Build object to Chromosome Class
# `random_chromsome` is a Build class object that can be assigned to `genome` argument in `Chromosome` class:

# %%
final_chromosome = Chromosome(genome = random_chromosome)
final_chromosome.review("elements")
# Out:
# Genomic Elements:
#               type name    start   finish eltype  \
# 0        noncoding  NaN        0     1794     g3
# 1795          exon  NaN     1795     2103     g1
# 2104        intron  NaN     2104     2644     g2
# 2645          exon  NaN     2645     2815     g1
# 2816        intron  NaN     2816     3289     g2
# ...            ...  ...      ...      ...    ...
# 1001810     intron  NaN  1001810  1002336     g2
# 1002337       exon  NaN  1002337  1002637     g1
# 1002638     intron  NaN  1002638  1003007     g2
# 1003008       exon  NaN  1003008  1003236     g1
# 1003237  noncoding  NaN  1003237   999999     g3
#
#                                                     script
# 0        <ElementType: 'None', g3, ['m1'], [1], mmJukes...
# 1795     <ElementType: 'None', g1, ['m3', 'm4'], [8, 0....
# 2104     <ElementType: 'None', g2, ['m3'], [1], mmJukes...
# 2645     <ElementType: 'None', g1, ['m3', 'm4'], [8, 0....
# 2816     <ElementType: 'None', g2, ['m3'], [1], mmJukes...
# ...                                                    ...
# 1001810  <ElementType: 'None', g2, ['m3'], [1], mmJukes...
# 1002337  <ElementType: 'None', g1, ['m3', 'm4'], [8, 0....
# 1002638  <ElementType: 'None', g2, ['m3'], [1], mmJukes...
# 1003008  <ElementType: 'None', g1, ['m3', 'm4'], [8, 0....
# 1003237  <ElementType: 'None', g3, ['m1'], [1], mmJukes...
#
# [1561 rows x 6 columns]

# %%
final_chromosome.review("chromosome")
# Out:
# Chromosome Summary
# # of Genes: 205
# Average # exons per gene: 3.8048780487804876
# Average exon length: 258.37179487179486 nt
# Average # introns per gene: 2.8048780487804876
# Average introns length: 454.95652173913044 nt
#
# Static Chromosome Plot:
# <div class="toyplot" id="tb5b9cdc5c3004f91ad68aa6f18e65054" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="3000.0px" height="200.0px" viewBox="0 0 3000.0 200.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t2330a57963934d8fa84c9000265c457a"><g class="toyplot-coordinates-Cartesian" id="td57ca4dbf08846fdae2ac903dbb38f6a"><clipPath id="t771ba0e1bc214b57b9e495fc78d706b1"><rect x="40.0" y="40.0" width="2920.0" height="120.0"></rect></clipPath><g clip-path="url(#t771ba0e1bc214b57b9e495fc78d706b1)"><g class="toyplot-mark-Range" style="stroke:none" id="t8644f453f46c4f6198509de421c738ce"><g class="toyplot-Series"><rect class="toyplot-Datum" x="50.0" y="50.0" width="5.185813521630479" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="tff53fbbfa4d142bfba66dbbd060c2763"><g class="toyplot-Series"><rect class="toyplot-Datum" x="55.188704164619125" y="50.0" width="0.8903180405028905" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="te7330fbb2be743b1865765e509b6dbd5"><g class="toyplot-Series"><rect class="toyplot-Datum" x="56.08191284811066" y="50.0" width="1.5609472138687082" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t209a044abef945ef8c031fbddf5dd54d"><g class="toyplot-Series"><rect class="toyplot-Datum" x="57.645750704968016" y="50.0" width="0.4914093080697839" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t654a006e4df640baac230ce70c67f8c5"><g class="toyplot-Series"><rect class="toyplot-Datum" x="58.140050656026446" y="50.0" width="1.3672741336294365" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t4dc58ebff3e843eba2c4e122585a1200"><g class="toyplot-Series"><rect class="toyplot-Datum" x="59.51021543264453" y="50.0" width="0.604144384626963" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t0349c9b8effe44d2b2ae0c7aec23f212"><g class="toyplot-Series"><rect class="toyplot-Datum" x="60.11725046026014" y="50.0" width="1.3990712065045443" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t548de8d8e8d4447496658c49bd9fd5b0"><g class="toyplot-Series"><rect class="toyplot-Datum" x="61.51921230975333" y="50.0" width="0.8469583956732052" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t5c415084df8f4add933e9fc67602913c"><g class="toyplot-Series"><rect class="toyplot-Datum" x="62.36906134841518" y="50.0" width="12.67546950521163" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t735019ccfa374171ba086e9d4a2ea686"><g class="toyplot-Series"><rect class="toyplot-Datum" x="75.04742149661546" y="50.0" width="0.8267238947526749" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t7dcd465a8e ...

# %% [markdown]
# ### Interactive Plot
# You can use the `review()` function to generate an interactive plot to inspect your chromosome structure further. Draw a region on the bottom plot to view that region in the top plot.

# %%
final_chromosome.review("interactive")
# Out:
# Interactive altair chromosome map:
# <div id="altair-viz-d847104f69ab4b3f8dd83c28e39e9785"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-d847104f69ab4b3f8dd83c28e39e9785") {
#       outputDiv = document.getElementById("altair-viz-d847104f69ab4b3f8dd83c28e39e9785");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "vconcat": [{"mark": "rect", "encoding": {"color": {"type": "nominal", "field": "altname", "scale": {"domain": ["exon", "intron", "noncoding"], "range": ["mediumvioletred", "lightgoldenrodyellow", "cornflowerblue"]}}, "tooltip": [{"type": "nominal", "field": "type", "title": "Element Type"}, {"type": "nominal", "field": "altname", "title": "Name"}, {"type": "quantitative", "field": "length", "title": "Length"}, {"type": "quantitative", "field": "x1", "title": "Start"}, {"type": "quantitative", "field": "x2", "title": "Stop"}], "x": {"type": "quantitative", "field": "x1", "scale": {"domain": {"selection": "selector001"}}, "title": null}, "x2": {"field": "x2"}, "y": {"type": "quantitative", "axis": null, "field": "y1"}, "y2": {"field": "y2"}}, "height": 80, "width": 850}, {"mark": "rect", "encoding": {"color": {"type": "nominal", "field": "altname", "scale": {"domain": ["exon", "intron", "noncoding"], "range": ["mediumvioletred", "lightgoldenrodyellow", "cornflowerblue"]}}, "tooltip": [{"type": "nominal", "field": "type", "title": "Element Type"}, {"type": "nominal", "field": "altname", "title": "Name"}, {"type": "quantitative", "field": "length", "title": "Length"}, {"type": "quantitative", "field": "x1", "title": "Start"}, {"type": "quantitative", "field": "x2", "title": "Stop"}], "x": {"type": "quantitative", "axis": {"title": "Base Pairs"}, "field": "x1"}, "x2": {"field": "x2"}, "y": {"type": "quantitative", "axis": null, "field": "y1"}, "y2": {"field": "y2"}}, "height": 40, "selection": {"selector001": {"type": "interval", "encodings": ["x"], "mark": {"fill": "red", "fillOpacity": 0.7}}}, "width": 850}], "data": {"name": "data-00e64811f77c89fc86565a57132604b5"}, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-00e64811f77c89fc86565a57132604b5": [{"type": "noncoding", "altname": "noncoding", "x1": 0, "x2": 1794.0, "y1": 0, "y2": 1, "length": 1794.0}, {"type": "exon", "altname": "exon", "x1": 1795, "x2": 2103.0, "y1": 0, "y2": 1, "length": 308.0}, {"type": "intron", "altname": "intron", "x1": 2104, "x2": 2644.0, "y1": 0, "y2": 1, "length": 540.0}, {"type": "exon", "altname": "exon", "x1": 2645, "x2": 2815.0, "y1": 0, "y2": 1, "length": 170.0}, {"type": "intron", "altname": "intron", "x1": 2816, "x2": 3289.0, "y1": 0, "y2": 1, "length": 473.0}, {"type": "exon", "altname": "exon", "x1": 3290, "x2": 3499.0, "y1": 0, "y2": 1, "length": 209.0}, {"type": "intron", "altname": "intron", "x1": 3500, "x2": 3984.0, "y1": 0, "y2": 1, "length": 484.0}, {"type": "exon", "altname": "exon", "x1": 3985, "x2": 4278.0, "y1": 0, "y2": 1, "length": 293.0}, {"type": "noncoding", "altname": "noncoding", "x1": 4279, "x2": 8664.0, "y1": 0, "y2": 1, "length": 4385.0}, {"type": "exon", "altname": "exon", "x1": 8665, "x2": 8951.0, "y1": 0, "y2": 1, "length": 286.0}, {"type": "intron", "altname": "intron", "x1": 8952, "x2": 9427.0, "y1": 0, "y2": 1, "length": 475.0}, {"type": "exon", "altname": "exon", "x1": 9428, "x2": 9710.0, "y1": 0, "y2": 1, "length": 282.0}, {"type": "intron", "altname": "intron", "x1": 9711, "x2": 10128.0, "y1": 0, "y2": 1, "length": 417.0}, {"type": "exon", "altname": "exon", "x1": 10129, "x2": 10275.0, "y1": 0, "y2": 1, "length": 146.0}, {"type": "intron", "altname": "intron", "x1": 10276, "x2": 10696.0, "y1": 0, "y2": 1, "length": 420.0}, {"type": "exon", "altname": "exon", "x1": 10697, "x2": 11038.0, "y1": 0, "y2": 1, "length": 341.0}, {"type": "intron", "altname": "intron", "x1": 11039, "x2": 11444.0, "y1": 0, "y2": 1, "length": 405.0}, {"type": "exon", "altname": "exon", "x1": 11445, "x2": 11704.0, "y1": 0, "y2": 1, "length": 259.0}, {"type": "intron", "altname": "intron", "x1": 11705, "x2": 12096.0, "y1": 0, "y2": 1, "length": 391.0}, {"type": "exon", "altname": "exon", "x1": 12097, "x2": 12319.0, "y1": 0, "y2": 1, "length": 222.0}, {"type": "intron", "altname": "intron", "x1": 12320, "x2": 12931.0, "y1": 0, "y2": ...

# %% [markdown]
# ## Random Chromosome with Custom Mutation Types & Genomic Element Types

# %%
from shadie import ElementList
from shadie import ElementType
from shadie import MutationType
from shadie import MutationList

#create your custom mutation types and save to a MutationList
mut1 = MutationType(0.5, "f", 0)
mut2 = MutationType(0.5, "e", 0.4)
mut3 = MutationType(0.5, "n", 0.4, .1)
mut4 = MutationType(0.5, "w", 0.3, 0.2)
mut5 = MutationType(0.5, "g", -0.4, .1)

mutlist = MutationList(mut1, mut2, mut3, mut4, mut5)

#create your custom genomic element types and save to an ElementList
noncod = ElementType(mut1, 1, altname = "nc")
exon1 = ElementType([mut2, mut5], [1, 1], altname = "ex1")
exon2 = ElementType([mut2, mut3, mut4], [9, 1, .02], altname = "ex2")
intron1 = ElementType([mut2, mut5], [1, 1], altname = "int1")
intron2 = ElementType([mut2, mut5], [1, 1], altname = "int2")

mycustomlist = ElementList(mutlist, noncod, exon1, exon2, intron1, intron2)
# Out:
# 01:50 | WARNING | __init__        | 'g', 'n', and 'w' distributions take 2 params
# 01:50 | WARNING | __init__        | 'g', 'n', and 'w' distributions take 2 params
# 01:50 | WARNING | __init__        | 'e' and 'f' distributions take 1 param
# 01:50 | WARNING | __init__        | 'e' and 'f' distributions take 1 param
# 01:50 | WARNING | __init__        | 'e' and 'f' distributions take 1 param

# %%
from shadie import Build

#initialize the Build class object
custom_build = Build(
    exons = [exon1, exon2], 
    introns = [intron1, intron2], 
    noncoding = [noncod], 
    elementlist = mycustomlist)

# %%
#run the same random function
custom_build.random()
# Out:
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Gene added
# 01:50 | INFO    | random          | Chromosome complete!

# %%
from shadie import Chromosome

customized_chrom = Chromosome(genome = custom_build)

# %%
customized_chrom.review("elements")
# Out:
# Genomic Elements:
#          name    start   finish eltype  \
# 0          nc        0     3847     g5
# 3848      ex1     3848     4063     g6
# 4064     int1     4064     4639     g8
# 4640      ex2     4640     4900     g7
# 4901       nc     4901     5780     g5
# ...       ...      ...      ...    ...
# 999020   int2   999020   999305     g9
# 999306    ex1   999306   999556     g6
# 999557   int1   999557  1000162     g8
# 1000163   ex1  1000163  1000346     g6
# 1000347    nc  1000347   999999     g5
#
#                                                     script       type
# 0                 'g5', c(m5),c(1), mmJukesCantor(1e-06/3)  noncoding
# 3848       'g6', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)       exon
# 4064       'g8', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)     intron
# 4640     'g7', c(m6, m7, m8),c(9, 1, 0.02), mmJukesCant...       exon
# 4901              'g5', c(m5),c(1), mmJukesCantor(1e-06/3)  noncoding
# ...                                                    ...        ...
# 999020     'g9', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)     intron
# 999306     'g6', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)       exon
# 999557     'g8', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)     intron
# 1000163    'g6', c(m6, m9),c(1, 1), mmJukesCantor(1e-06/3)       exon
# 1000347           'g5', c(m5),c(1), mmJukesCantor(1e-06/3)  noncoding
#
# [1705 rows x 6 columns]

# %%
import pandas as pd
final_chromosome.genome["name"]

for index, row in final_chromosome.genome.iterrows():
    if pd.isna(row['name']):
        print(row['type'])
    else: 
        print(row['name'])
# Out:
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# noncoding
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# intron
# exon
# noncoding

# %%
customized_chrom.review("chromosome")
# Out:
# Chromosome Summary
# # of Genes: 220
# Average # exons per gene: 3.8727272727272726
# Average exon length: 259.46596244131456 nt
# Average # introns per gene: 2.8727272727272726
# Average introns length: 452.40822784810126 nt
#
# Static Chromosome Plot:
# <div class="toyplot" id="tb40ff5d29ae14e22aea8aa46f81b8bf4" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="3000.0px" height="200.0px" viewBox="0 0 3000.0 200.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t41e8998361944cd188a69d0495f63082"><g class="toyplot-coordinates-Cartesian" id="tda58501b7e4940a18e6ff8f94acf6d22"><clipPath id="t43ecd3b3d9ca476fb883d90e733fab62"><rect x="40.0" y="40.0" width="2920.0" height="120.0"></rect></clipPath><g clip-path="url(#t43ecd3b3d9ca476fb883d90e733fab62)"><g class="toyplot-mark-Range" style="stroke:none" id="ta0dcfc221af148eb8e58334d2f1d2956"><g class="toyplot-Series"><rect class="toyplot-Datum" x="50.0" y="50.0" width="11.15243010675296" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t74a2d2af60294ae7b2f8f6e919985e23"><g class="toyplot-Series"><rect class="toyplot-Datum" x="61.15532910080202" y="50.0" width="0.6232837205489687" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t5cf36de5d91146ba8c038f0f57d4742e"><g class="toyplot-Series"><rect class="toyplot-Datum" x="61.78151181540006" y="50.0" width="1.666921578212353" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t88340ff0fbbc4c8cae485af06ef6a6c2"><g class="toyplot-Series"><rect class="toyplot-Datum" x="63.45133238766148" y="50.0" width="0.7537384527568918" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t18b64431de7b40bc87f8b721b56e3924"><g class="toyplot-Series"><rect class="toyplot-Datum" x="64.20796983446743" y="50.0" width="2.54821576912812" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t0dfee1fdb7104631883ff6d64284ebf1"><g class="toyplot-Series"><rect class="toyplot-Datum" x="66.75908459764462" y="50.0" width="1.316143298275506" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t5459ea3dde054985864b48ce6491c544"><g class="toyplot-Series"><rect class="toyplot-Datum" x="68.07812688996918" y="50.0" width="4.606501543964242" height="100.0" style="fill:rgb(69.8%,13.3%,13.3%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t892f7d81d9ce488c879ed96412b17b9d"><g class="toyplot-Series"><rect class="toyplot-Datum" x="72.68752742798249" y="50.0" width="1.3045473220792445" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t621ce3aa92e8407f955c8bdfb325be46"><g class="toyplot-Series"><rect class="toyplot-Datum" x="73.9949737441108" y="50.0" width="1.142203655331599" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="t589368b362c44d6b851255f085ef9c33"><g class="toyplot-Series"><rect class="toyplot-Datum" x="75.14007639349146" y="50.0" width="0.6464756729414916" height="100.0" style="fill:rgb(27.5%,51%,70.6%);fill-opacity:1.0;opacity:1.0;stroke:none"></rect></g></g><g class="toyplot-mark-Range" style="stroke:none" id="tbc1565eac38344 ...

# %%
customized_chrom.review("interactive")
# Out:
# Interactive altair chromosome map:
# <div id="altair-viz-66b5e872d5574a3aaf7b7f1087efb7ff"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-66b5e872d5574a3aaf7b7f1087efb7ff") {
#       outputDiv = document.getElementById("altair-viz-66b5e872d5574a3aaf7b7f1087efb7ff");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "vconcat": [{"mark": "rect", "encoding": {"color": {"type": "nominal", "field": "altname", "scale": {"domain": ["ex1", "ex2", "int1", "int2", "nc"], "range": ["mediumvioletred", "lightcoral", "lightgoldenrodyellow", "gold", "cornflowerblue"]}}, "tooltip": [{"type": "nominal", "field": "type", "title": "Element Type"}, {"type": "nominal", "field": "altname", "title": "Name"}, {"type": "quantitative", "field": "length", "title": "Length"}, {"type": "quantitative", "field": "x1", "title": "Start"}, {"type": "quantitative", "field": "x2", "title": "Stop"}], "x": {"type": "quantitative", "field": "x1", "scale": {"domain": {"selection": "selector002"}}, "title": null}, "x2": {"field": "x2"}, "y": {"type": "quantitative", "axis": null, "field": "y1"}, "y2": {"field": "y2"}}, "height": 80, "selection": {"selector002": {"type": "interval", "encodings": ["x"], "mark": {"fill": "red", "fillOpacity": 0.7}}}, "width": 850}, {"mark": "rect", "encoding": {"color": {"type": "nominal", "field": "altname", "scale": {"domain": ["ex1", "ex2", "int1", "int2", "nc"], "range": ["mediumvioletred", "lightcoral", "lightgoldenrodyellow", "gold", "cornflowerblue"]}}, "tooltip": [{"type": "nominal", "field": "type", "title": "Element Type"}, {"type": "nominal", "field": "altname", "title": "Name"}, {"type": "quantitative", "field": "length", "title": "Length"}, {"type": "quantitative", "field": "x1", "title": "Start"}, {"type": "quantitative", "field": "x2", "title": "Stop"}], "x": {"type": "quantitative", "axis": {"title": "Base Pairs"}, "field": "x1"}, "x2": {"field": "x2"}, "y": {"type": "quantitative", "axis": null, "field": "y1"}, "y2": {"field": "y2"}}, "height": 40, "selection": {"selector002": {"type": "interval", "encodings": ["x"], "mark": {"fill": "red", "fillOpacity": 0.7}}}, "width": 850}], "data": {"name": "data-2d22ffd5ccd88531e548fe92d354df43"}, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-2d22ffd5ccd88531e548fe92d354df43": [{"type": "noncoding", "altname": "nc", "x1": 0, "x2": 3847.0, "y1": 0, "y2": 1, "length": 3847.0}, {"type": "exon", "altname": "ex1", "x1": 3848, "x2": 4063.0, "y1": 0, "y2": 1, "length": 215.0}, {"type": "intron", "altname": "int1", "x1": 4064, "x2": 4639.0, "y1": 0, "y2": 1, "length": 575.0}, {"type": "exon", "altname": "ex2", "x1": 4640, "x2": 4900.0, "y1": 0, "y2": 1, "length": 260.0}, {"type": "noncoding", "altname": "nc", "x1": 4901, "x2": 5780.0, "y1": 0, "y2": 1, "length": 879.0}, {"type": "exon", "altname": "ex2", "x1": 5781, "x2": 6235.0, "y1": 0, "y2": 1, "length": 454.0}, {"type": "noncoding", "altname": "nc", "x1": 6236, "x2": 7825.0, "y1": 0, "y2": 1, "length": 1589.0}, {"type": "exon", "altname": "ex2", "x1": 7826, "x2": 8276.0, "y1": 0, "y2": 1, "length": 450.0}, {"type": "intron", "altname": "int1", "x1": 8277, "x2": 8671.0, "y1": 0, "y2": 1, "length": 394.0}, {"type": "exon", "altname": "ex1", "x1": 8672, "x2": 8895.0, "y1": 0, "y2": 1, "length": 223.0}, {"type": "intron", "altname": "int1", "x1": 8896, "x2": 9321.0, "y1": 0, "y2": 1, "length": 425.0}, {"type": "exon", "altname": "ex2", "x1": 9322, "x2": 9630.0, "y1": 0, "y2": 1, "length": 308.0}, {"type": "intron", "altname": "int1", "x1": 9631, "x2": 10137.0, "y1": 0, "y2": 1, "length": 506.0}, {"type": "exon", "altname": "ex1", "x1": 10138, "x2": 10437.0, "y1": 0, "y2": 1, "length": 299.0}, {"type": "noncoding", "altname": "nc", "x1": 10438, "x2": 10812.0, "y1": 0, "y2": 1, "length": 374.0}, {"type": "exon", "altname": "ex2", "x1": 10813, "x2": 10978.0, "y1": 0, "y2": 1, "length": 165.0}, {"type": "noncoding", "altname": "nc", "x1": 10979, "x2": 12614.0, "y1": 0, "y2": 1, "length": 1635.0}, {"type": "exon", "altname": "ex1", "x1": 12615, "x2": 12927.0, "y1": 0, "y2": 1, "length": 312.0}, {"type": "noncoding", "altname": "nc", "x1": 12928, "x2": 13763.0, "y1": 0, "y2": 1, "length": 835.0}, {"type": "exon", "altname": "ex1", "x1": 1376 ...

# %% [markdown]
# ## Custom Chromosome
# Finally, you can define your own chromosome by providing a pandas dataframe that contains, at minimum, the `name` of the genomic element (as defined by you *or* using `shadie` defaults), the `start base` and the `end base`. Alternatively, you can provide the internal `idx` of the genomic element (in place of the `name`). You must provide a GenomeList class object and your genomic elements must be defined in the list.
