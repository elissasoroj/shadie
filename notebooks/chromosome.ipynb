# %%
import sys
sys.path.append("/home/deren/Documents/shadie")

# %%
import shadie
import shadie.genomic_elements
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-d98de2586166> in <module>
#       1 import shadie
# ----> 2 import shadie.genomic_elements
#
# ~/Documents/shadie/shadie/genomic_elements.py in <module>
#       5 """
#       6
# ----> 7 from mutations import Neutral, Synonymous, Deleterious, Beneficial
#       8
#       9
#
# ModuleNotFoundError: No module named 'mutations'

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    columns=['etype', 'start', 'end', 'element'],
    index=range(20),
    dtype=(str, int),
)

df.loc[0] = shadie.genomic_elements.NonCoding(0, 100, [shadie.mutations.Neutral(0.5, 0.0)], [1.0])
df
# Out:
#                      etype                   start                     end  \
# 0   (g101, c(m98), c(1.0))  (g101, c(m98), c(1.0))  (g101, c(m98), c(1.0))
# 1                      NaN                     NaN                     NaN
# 2                      NaN                     NaN                     NaN
# 3                      NaN                     NaN                     NaN
# 4                      NaN                     NaN                     NaN
# 5                      NaN                     NaN                     NaN
# 6                      NaN                     NaN                     NaN
# 7                      NaN                     NaN                     NaN
# 8                      NaN                     NaN                     NaN
# 9                      NaN                     NaN                     NaN
# 10                     NaN                     NaN                     NaN
# ...

# %%
with initialize():
    Model("nonWF")
    Neutral("m1", 0.5, "f", 0.0)
# Out:
# <class 'shadie.mutations.Neutral'> ('m100', 0.5, 'f')>
